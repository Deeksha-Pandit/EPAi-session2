# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeksha-Pandit/EPAi-session2/blob/main/session10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading https://files.pythonhosted.org/packages/4e/6a/591bea01ef396a4611b2097af19aa86975ebef06a4bb571a8a25ba36cf9a/Faker-6.1.1-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 7.8MB/s
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from Faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.6/dist-packages (from Faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.4->Faker) (1.15.0)
# Installing collected packages: Faker
# Successfully installed Faker-6.1.1

# %%
from faker import Faker
from collections import namedtuple
import datetime
from datetime import datetime
fake = Faker()

# %%
def fake_profile():
    '''
    This function is used to generate 10000 profiles using the faker module in python
    It stores all this data in namedtuple
    '''
    p = []
    start = datetime.now()
    faker_profile = namedtuple('faker_profile',fake.profile().keys())
    for i in range(10000):
        p.append(faker_profile(**fake.profile()))
    end = datetime.now()
    print(end-start)
    return p
fake_profile()
# Out:
# 0:00:17.457710
# [faker_profile(job='Public relations officer', company='Sharp, Anderson and Martinez', ssn='284-10-5274', residence='7972 Jennifer Corner\nNew Timothyview, PA 79123', current_location=(Decimal('-16.5926005'), Decimal('-66.865939')), blood_group='O-', website=['https://www.morrison-castro.com/'], username='jessicahernandez', name='Shawna Bates', sex='F', address='72140 Benjamin Hollow Apt. 896\nDouglasburgh, NY 82549', mail='cameron86@gmail.com', birthdate=datetime.date(1951, 4, 9)),
#  faker_profile(job='Logistics and distribution manager', company='Hubbard, Todd and Barrera', ssn='304-59-7558', residence='7702 Shane Islands Suite 616\nGarzaside, MS 86888', current_location=(Decimal('52.8001215'), Decimal('33.468407')), blood_group='AB-', website=['https://bates.biz/', 'http://gonzalez.com/'], username='peterwalter', name='Heather Navarro', sex='F', address='161 Sarah Loaf\nSouth Kerry, IL 83438', mail='mitchell31@hotmail.com', birthdate=datetime.date(1959, 2, 19)),
#  faker_profile(job='Public affairs consultant', company='Townsend, Jordan and Washington', ssn='411-74-5280', residence='36716 Garcia Knolls\nPort John, NM 60871', current_location=(Decimal('7.034203'), Decimal('-72.033006')), blood_group='A-', website=['https://www.scott.com/', 'http://www.cabrera.net/', 'https://www.lee.com/'], username='laura75', name='Antonio Mcneil', sex='M', address='082 Dale Heights Apt. 925\nPatrickmouth, SC 48814', mail='leslie59@yahoo.com', birthdate=datetime.date(1909, 10, 18)),
#  faker_profile(job='Systems analyst', company='Harrison Group', ssn='630-33-1580', residence='3901 Wright Mission\nSmallton, NM 62969', current_location=(Decimal('-21.590888'), Decimal('23.797459')), blood_group='B+', website=['https://jackson.com/', 'https://www.compton.com/'], username='wbowman', name='Randy Reese', sex='M', address='3170 Mia Greens Apt. 813\nWest Christophertown, NJ 72931', mail='davisnatasha@yahoo.com', birthdate=datetime.date(1996, 7, 24)),
#  faker_profile(job='Community development worker', company='Dean-Dominguez', ssn='523-61-7667', residence='Unit 1590 Box 5331\nDPO AA 45079', current_location=(Decimal('5.2144175'), Decimal('-52.794578')), blood_group='A+', website=['https://reed-pittman.com/', 'https://maldonado.biz/'], username='villachristine', name='Erica Warner', sex='F', address='USNS Sullivan\nFPO AE 22617', mail='xstewart@yahoo.com', birthdate=datetime.date(2005, 10, 27)),
#  faker_profile(job='Engineer, chemical', company='Frye, Porter and Davis', ssn='893-88-3539', residence='6997 Brown Islands Apt. 209\nPort Ashley, MN 60622', current_location=(Decimal('-55.034969'), Decimal('-165.516485')), blood_group='B+', website=['https://curtis.com/', 'https://www.smith-williamson.biz/'], username='michellehall', name='Tricia Robertson', sex='F', address='0095 Sanchez Spur\nHurstshire, NJ 81811', mail='lindaevans@gmail.com', birthdate=datetime.date(2010, 6, 12)),
#  faker_profile(job='Copy', company='Ortiz, Jensen and Smith', ssn='660-20-8697', residence='4123 Anthony Forge Apt. 740\nTurnerville, NV 13276', current_location=(Decimal('-54.004010'), Decimal('-116.292534')), blood_group='AB+', website=['http://mclaughlin.com/', 'https://www.holland.com/', 'http://reyes-lopez.net/'], username='herreratracy', name='Justin Diaz', sex='M', address='073 Cindy Groves\nWest Rachelfurt, ND 57253', mail='morganeric@hotmail.com', birthdate=datetime.date(1956, 4, 9)),
#  faker_profile(job='Energy manager', company='Willis PLC', ssn='112-38-8133', residence='45017 Martinez Glen Apt. 309\nContrerasborough, OK 35385', current_location=(Decimal('5.589841'), Decimal('109.502784')), blood_group='AB+', website=['https://www.smith.org/', 'https://perry.biz/', 'http://www.riley-gentry.info/'], username='tammydixon', name='Stacey Oconnor', sex='F', address='6002 Carrie Shores Apt. 293\nSmithport, LA 70635', mail='robert72@hotmail.com', birthdate=datetime.date(1928, 11, 24)),
#  faker_profile(job='Industrial buyer', company='Vargas-Levy', ssn='612-99-3655', residence='83862 Dennis Centers Suite 636\nNorth Carlafort, GA 81411', current_location=(Decimal('37.194634'), Decimal('-34.588374')), blood_group='B-', website=['https://www.bonilla.org/'], username='lewisalan', name='Dakota Nelson', sex='M', address='687 Shea Alley Suite 749\nMeghanland, NV 25614', mail='angelamills@gmail.com', birthdate=datetime.date(2017, 2, 20)),
#  faker_profile(job='Chartered public finance accountant', company='Irwin-Hoover', ssn='771-54-3425', residence='61770 Parsons Pass\nSouth Tracey, CO 15665', current_location=(Decimal('-72.722832'), Decimal('148.511712')), blood_group='AB+', website=['http://www.barrera.com/', 'https://little.com/'], username='smithsarah', name='Lori Lara DDS', sex='F', address='83945 Weber Wells Suite 937\nMarcview, NH 12087', mail='xjensen@hotmail.com', birthdate=datetime.date(2013, 3, 3)),
#  faker_profile(job='Building services engineer', company='Cannon, Solomon and Delgado', ssn='668-29-4323', residence='6324 James Court\nEast Thomas, NC 95797', current_location=(Decimal('-71.6523315'), Decimal('161.366183')), blood_group='A-', website=['http://mccullough-elliott.com/', 'https://www.osborn.com/', 'http://jenkins-fernandez.org/'], username='porterjeanne', name='Diane Thomas', sex='F', address='070 Debra Camp Apt. 707\nNorth Zacharyfort, VA 09279', mail='michele40@gmail.com', birthdate=datetime.date(1907, 1, 30)),
#  faker_profile(job='Adult guidance worker', company='Sampson and Sons', ssn='791-60-3123', residence='1879 David Mountains Suite 711\nDelacruztown, PA 49541', current_location=(Decimal('61.7901665'), Decimal('81.273820')), blood_group='AB+', website=['https://pearson-brown.org/', 'https://www.richards-lopez.com/', 'https://www.white-escobar.com/', 'https://moyer.com/'], username='lisa42', name='Vanessa Meyer', sex='F', address='52221 Lauren Knolls\nHernandezburgh, NJ 08929', mail='dillon44@gmail.com', birthdate=datetime.date(1966, 4, 10)),
#  faker_profile(job='Paediatric nurse', company='Mercado and Sons', ssn='034-64-0073', residence='361 Donna Manor Apt. 485\nStevenberg, NJ 28976', current_location=(Decimal('-0.090520'), Decimal('-77.627920')), blood_group='B+', website=['http://www.torres.com/'], username='eddie02', name='Ashley Moran', sex='F', address='97378 Luis Spring\nPort Robert, HI 97176', mail='frankcastro@hotmail.com', birthdate=datetime.date(1975, 7, 27)),
#  faker_profile(job='Charity officer', company='Mooney Inc', ssn='885-86-9945', residence='8218 Joshua Falls Suite 362\nNew Terriberg, WY 66271', current_location=(Decimal('-45.1198755'), Decimal('-179.168726')), blood_group='O+', website=['https://shaw.org/'], username='cryan', name='John Anderson', sex='M', address='8352 Castro Port Suite 788\nNorth Teresa, KS 19710', mail='timothy65@hotmail.com', birthdate=datetime.date(1993, 6, 7)),
#  faker_profile(job='Community development worker', company='Morgan, Vasquez and Miller', ssn='371-61-3623', residence='29126 Ortega Camp Suite 936\nNew Stephanie, NY 95493', current_location=(Decimal('-23.085550'), Decimal('82.749933')), blood_group='B-', website=['https://www.lamb.com/', 'https://www.gibson-hamilton.com/', 'http://pratt.com/', 'https://www.baker.com/'], username='reynoldscody', name='Courtney Flores', sex='F', address='8705 Jessica Cape Apt. 768\nWest Shelby, OR 81642', mail='twilson@yahoo.com', birthdate=datetime.date(1964, 2, 22)),
#  faker_profile(job='Psychotherapist', company='Gonzales PLC', ssn='853-59-1659', residence='738 Heidi Divide\nLawrenceshire, TN 10183', current_location=(Decimal('-18.3926205'), Decimal('-40.702845')), blood_group='O-', website=['https://www.gardner.net/'], username='scott95', name='Randy Wilson', sex='M', address='3464 Christopher Brook Apt. 787\nNew Amberport, MN 94437', mail='lisa38@yahoo.com', birthdate=datetime.date(1988, 3, 27)),
#  faker_profile(job='Therapist, horticultural', company='Hernandez-Hunt', ssn='639-42-6866', residence='9914 James Isle Suite 882\nBairdville, KY 08412', current_location=(Decimal('32.3730265'), Decimal('38.500191')), blood_group='AB-', website=['http://gutierrez.com/'], username='hschultz', name='Ryan Richardson', sex='M', address='73525 Farrell Common Suite 303\nShelleystad, WV 06224', mail='zachary34@yahoo.com', birthdate=datetime.date(2016, 11, 20)),
#  faker_profile(job='Surveyor, hydrographic', company='Spencer-Weber', ssn='526-16-1490', residence='3204 Serrano Spur\nGuerramouth, CA 04516', current_location=(Decimal('76.359419'), Decimal('-141.325169')), blood_group='B-', website=['http://www.diaz.com/', 'https://www.robles-fowler.biz/', 'https://anderson-watts.com/'], username='tracey99', name='Kelly Marsh', sex='F', address='67042 Graham Road Apt. 947\nLake Angela, NE 84384', mail='ryan08@hotmail.com', birthdate=datetime.date(1942, 12, 2)),
#  faker_profile(job='Hydrogeologist', company='Cervantes PLC', ssn='404-89-2754', residence='9206 Mayer Canyon Suite 949\nDonaldview, DE 13410', current_location=(Decimal('39.031494'), Decimal('154.176079')), blood_group='AB-', website=['http://www.anderson-ferguson.net/', 'http://www.schultz.com/', 'https://wheeler.biz/'], username='sarahmoran', name='Pamela Smith', sex='F', address='USNS Kelley\nFPO AE 27968', mail='deborah23@yahoo.com', birthdate=datetime.date(2020, 8, 13)),
#  faker_profile(job='Restaurant manager', company='Randall, Manning and Mendez', ssn='404-18-9166', residence='22883 Sally Falls\nSpencershire, IN 18486', current_location=(Decimal('-18.5710635'), Decimal('84.094985')), blood_group='A+', website=['http://andrews.biz/'], username='uwhite', name='Calvin Bell', sex='M', address='35353 Jennifer Union Suite 140\nNormanmouth, NE 47056', mail='barreratodd@yahoo.com', birthdate=datetime.date(2003, 9, 24)),
#  faker_profile(job='Manufacturing engineer', company='Thomas PLC', ssn='083-29-4188', residence='7563 Omar Meadow Apt. 987\nColemanmouth, FL 00690', current_location=(Decimal('-21.9967885'), Decimal('57.729712')), blood_group='B+', website=['http://andersen.com/', 'http://mckenzie.com/', 'http://www.anderson.net/', 'http://www.howard.com/'], username='crystalpierce', name='Beth Clark', sex='F', address='310 Lisa Stravenue\nPort Michael, NV 79624', mail='blackerika@yahoo.com', birthdate=datetime.date(1910, 5, 28)),
#  faker_profile(job='Clinical psychologist', company='Yang-Garrison', ssn='204-46-4002', residence='046 Santana Hill\nCrawfordview, MS 14525', current_location=(Decimal('63.7828665'), Decimal('47.026242')), blood_group='AB-', website=['https://hill.biz/', 'https://carson-aguilar.com/'], username='john69', name='Christopher Ford', sex='M', address='739 Brian Roads Apt. 641\nWongchester, HI 51332', mail='kylezuniga@yahoo.com', birthdate=datetime.date(1992, 8, 13)),
#  faker_profile(job='Scientist, clinical (histocompatibility and immunogenetics)', company='Wagner and Sons', ssn='898-33-0719', residence='4693 Kristin Harbor Apt. 416\nSouth Audreychester, WV 16955', current_location=(Decimal('72.6741855'), Decimal('-118.650668')), blood_group='A-', website=['https://www.collier.org/'], username='pbowen', name='Brittany Jones', sex='F', address='464 Smith Village\nNew Sue, MI 10761', mail='frodriguez@hotmail.com', birthdate=datetime.date(1996, 12, 7)),
#  faker_profile(job='Chief Executive Officer', company='Johnston, Vasquez and Perkins', ssn='244-96-6914', residence='0750 Mckenzie Junction Apt. 630\nSouth Charlesville, MA 93251', current_location=(Decimal('-4.599909'), Decimal('-8.123373')), blood_group='AB+', website=['http://www.williams.org/', 'https://smith.com/'], username='melissascott', name='Vanessa Evans', sex='F', address='USNV Gonzales\nFPO AP 31723', mail='michaeledwards@yahoo.com', birthdate=datetime.date(2008, 9, 3)),
#  faker_profile(job='Art gallery manager', company='Green Inc', ssn='628-24-3574', residence='34070 Dawn Squares\nAnthonyhaven, MT 07780', current_location=(Decimal('28.6118405'), Decimal('91.734453')), blood_group='B+', website=['http://stevens-lopez.com/'], username='blackcaleb', name='Crystal Bautista', sex='F', address='73094 Jonathan Springs Apt. 443\nNorth William, NM 40507', mail='lmoore@hotmail.com', birthdate=datetime.date(2000, 9, 18)),
#  faker_profile(job='Retail merchandiser', company='Myers and Sons', ssn='066-89-3045', residence='87640 Williams Mountains\nLake Briannafurt, WY 96575', current_location=(Decimal('-65.068062'), Decimal('-129.226933')), blood_group='AB+', website=['https://reese.com/', 'https://clark.net/', 'https://www.goodwin.com/', 'http://winters.com/'], username='hmoore', name='Anna Brown', sex='F', address='USCGC Miles\nFPO AE 17303', mail='sarahbowen@hotmail.com', birthdate=datetime.date(2010, 11, 16)),
#  faker_profile(job='Rural practice surveyor', company='Dominguez, Larson and Potts', ssn='854-09-4793', residence='93381 Joe Field\nWest Sherry, VA 64789', current_location=(Decimal('-88.689438'), Decimal('-173.328788')), blood_group='AB-', website=['https://cruz.com/'], username='dcasey', name='Kyle Martinez', sex='M', address='57906 Tiffany Mountain Suite 890\nNorth Kellyton, AL 10758', mail='rwhite@gmail.com', birthdate=datetime.date(1966, 4, 23)),
#  faker_profile(job='Multimedia programmer', company='Owens, Cooke and Wood', ssn='785-05-0985', residence='422 Oconnell Shoals Apt. 698\nSmithtown, DE 77075', current_location=(Decimal('87.1772855'), Decimal('176.276260')), blood_group='O+', website=['https://yates.biz/', 'https://fowler.com/'], username='norrisapril', name='Caitlin Wiggins', sex='F', address='68191 Berry Streets\nPort Jason, TX 31464', mail='obrandt@yahoo.com', birthdate=datetime.date(1985, 1, 23)),
#  faker_profile(job='Engineer, energy', company='Tucker Inc', ssn='588-67-1023', residence='371 Samuel Harbors Suite 148\nKristinland, DC 68278', current_location=(Decimal('-13.951576'), Decimal('-11.339848')), blood_group='O+', website=['http://watts.info/', 'http://rose.biz/', 'https://henderson-watkins.com/'], username='laurenpeters', name='Jessica Roth', sex='F', address='90015 Leslie Stream Apt. 473\nSouth Scott, MT 89981', mail='jamesdawson@gmail.com', birthdate=datetime.date(1959, 7, 12)),
#  faker_profile(job='Leisure centre manager', company='Pope, Richardson and Baker', ssn='033-44-1739', residence='9384 Erica Cove\nRodriguezport, MT 16387', current_location=(Decimal('-34.0833345'), Decimal('15.862698')), blood_group='AB+', website=['http://www.hays.info/'], username='xfuller', name='Benjamin Moody', sex='M', address='815 Murphy Mews\nLake Jenniferburgh, TN 86901', mail='kjohnson@gmail.com', birthdate=datetime.date(1934, 7, 26)),
#  faker_profile(job='Local government officer', company='White Inc', ssn='243-07-7330', residence='53934 Hardy Stream Suite 854\nPortershire, TX 64788', current_location=(Decimal('41.5912195'), Decimal('72.572964')), blood_group='O-', website=['http://www.guerrero.com/', 'https://www.lowery-hernandez.info/', 'https://www.white-mcgrath.info/'], username='eddiefreeman', name='Eric Reynolds', sex='M', address='667 Katie Flat\nAbigailfort, IL 15981', mail='wilkersonallison@hotmail.com', birthdate=datetime.date(1989, 9, 14)),
#  faker_profile(job='Psychologist, forensic', company='Fuentes and Sons', ssn='704-49-9212', residence='54548 Montoya Point Suite 973\nReneemouth, MD 80768', current_location=(Decimal('-84.871335'), Decimal('-77.662357')), blood_group='B+', website=['http://briggs.com/', 'https://burton.org/', 'http://www.alvarez.info/'], username='terri87', name='Terry Nash', sex='F', address='730 Denise Tunnel\nScottmouth, NM 15590', mail='allisonlong@gmail.com', birthdate=datetime.date(1974, 2, 8)),
#  faker_profile(job='Pharmacist, community', company='Green Ltd', ssn='472-79-6455', residence='18837 Morrison Springs Apt. 374\nAndersonchester, WA 62069', current_location=(Decimal('-39.2181675'), Decimal('-53.111207')), blood_group='AB+', website=['https://murphy.net/', 'https://miller.org/', 'https://russell-andrews.com/'], username='urobinson', name='Rebecca Peterson', sex='F', address='047 Smith Avenue\nDavidside, AZ 96308', mail='julie47@gmail.com', birthdate=datetime.date(1923, 4, 6)),
#  faker_profile(job='Learning mentor', company='Green-Stephens', ssn='709-82-7096', residence='825 Mary Forks\nDavisstad, FL 70935', current_location=(Decimal('61.1123215'), Decimal('-151.202945')), blood_group='O-', website=['http://www.hernandez.com/', 'https://www.chapman.biz/', 'http://www.johnson.net/', 'http://wagner-ruiz.com/'], username='diana62', name='Marie Gray', sex='F', address='4299 Davis Manor\nBrendaview, NC 01998', mail='cindykrause@hotmail.com', birthdate=datetime.date(2018, 11, 16)),
#  faker_profile(job='Administrator, local government', company='Sweeney and Sons', ssn='362-45-4363', residence='7801 Jay Fort Apt. 106\nJillport, OH 45293', current_location=(Decimal('-62.0435785'), Decimal('-84.251508')), blood_group='O-', website=['http://www.rivera.net/', 'http://www.sherman.com/', 'https://bradshaw.net/'], username='joshua97', name='Linda Woods', sex='F', address='730 Payne Squares\nSouth Justinbury, ID 33671', mail='hrojas@gmail.com', birthdate=datetime.date(1946, 3, 31)),
#  faker_profile(job='Company secretary', company='Ray Inc', ssn='831-43-5383', residence='84260 Ernest Union Apt. 588\nNew Michael, IN 60834', current_location=(Decimal('58.439751'), Decimal('54.290826')), blood_group='AB-', website=['http://www.mendoza.info/', 'https://www.miller.com/', 'https://www.beltran.com/', 'http://rowland-fritz.com/'], username='webersean', name='Shannon Holmes', sex='F', address='246 Alexander Ways Apt. 443\nEricamouth, NY 68269', mail='shirleywalters@gmail.com', birthdate=datetime.date(1937, 4, 9)),
#  faker_profile(job='Accountant, chartered', company='Reese-Ellison', ssn='841-07-5421', residence='78967 Brian Track\nNataliehaven, AK 73237', current_location=(Decimal('21.6983055'), Decimal('-41.555601')), blood_group='A+', website=['http://www.tucker.com/', 'http://herman.com/', 'http://smith.com/'], username='newmanchristine', name='Tammy Escobar', sex='F', address='992 Craig Island Apt. 661\nFernandezfurt, MT 10186', mail='birdjennifer@hotmail.com', birthdate=datetime.date(1963, 9, 5)),
#  faker_profile(job='Civil Service fast streamer', company='Wallace, Hernandez and Bell', ssn='447-78-4613', residence='8103 Woods Stravenue Apt. 164\nLake Williamburgh, TX 59026', current_location=(Decimal('-57.681917'), Decimal('-146.256631')), blood_group='O+', website=['http://www.gonzalez.com/', 'https://baldwin-anderson.net/', 'https://stokes-burnett.com/', 'https://www.dixon-ball.net/'], username='ypratt', name='Amanda Conner', sex='F', address='57181 Walter Ford Suite 848\nKelleybury, KS 08119', mail='thomas64@hotmail.com', birthdate=datetime.date(1911, 1, 31)),
#  faker_profile(job='Emergency planning/management officer', company='Martin, Hamilton and Young', ssn='501-07-3774', residence='765 Johnston Mountains Suite 600\nQuinnmouth, NV 70291', current_location=(Decimal('55.829801'), Decimal('172.094504')), blood_group='B+', website=['https://www.thompson.biz/', 'http://dyer.com/'], username='daniel66', name='Jackie Zamora', sex='F', address='1299 Russell Isle\nWest Miranda, ND 42802', mail='michelle17@gmail.com', birthdate=datetime.date(2019, 4, 29)),
#  faker_profile(job='Youth worker', company='Gomez-Gibbs', ssn='068-57-1788', residence='Unit 4457 Box 1696\nDPO AA 88210', current_location=(Decimal('-16.919839'), Decimal('140.158471')), blood_group='O-', website=['http://austin.net/', 'https://stein-livingston.com/', 'https://www.rodriguez.com/', 'http://wheeler-waters.com/'], username='jeremyewing', name='Ashley Burton', sex='F', address='754 Woodward Port Apt. 730\nStewartberg, IA 20888', mail='mgrant@yahoo.com', birthdate=datetime.date(1966, 5, 2)),
#  faker_profile(job='Insurance claims handler', company='Morris, Fisher and Hernandez', ssn='717-43-7211', residence='Unit 3892 Box 3685\nDPO AA 36705', current_location=(Decimal('65.330846'), Decimal('-76.668463')), blood_group='B-', website=['http://johnson.com/', 'http://www.miller.com/'], username='simpsonchristina', name='Annette Gomez', sex='F', address='758 Howard Highway Suite 772\nNew Rodney, NE 36113', mail='hheath@yahoo.com', birthdate=datetime.date(1970, 11, 11)),
#  faker_profile(job='Engineer, energy', company='Simmons, Medina and Gordon', ssn='677-83-8835', residence='472 Jason Lights Apt. 772\nEast Eric, WY 95686', current_location=(Decimal('-0.2599395'), Decimal('8.013836')), blood_group='A+', website=['https://branch.com/', 'https://www.jones.com/'], username='kennethcastillo', name='Kenneth Skinner', sex='M', address='793 Cory Drive Suite 069\nNorth Jacquelinemouth, AR 07050', mail='nicolejackson@hotmail.com', birthdate=datetime.date(2017, 2, 12)),
#  faker_profile(job='Animal technologist', company='Steele-Hernandez', ssn='208-62-0266', residence='USNS Fitzpatrick\nFPO AP 29741', current_location=(Decimal('-2.334802'), Decimal('153.789049')), blood_group='B+', website=['http://kelley-carter.com/', 'http://galloway-flores.info/', 'http://www.silva.com/', 'https://www.smith.com/'], username='hawkinsbrad', name='Christopher Lopez', sex='M', address='95920 Amanda Plains Suite 533\nLake Lauren, FL 81141', mail='svang@yahoo.com', birthdate=datetime.date(1952, 10, 5)),
#  faker_profile(job='Television camera operator', company='Campbell, Donovan and Murphy', ssn='667-83-9562', residence='Unit 6376 Box 2360\nDPO AA 57071', current_location=(Decimal('54.684404'), Decimal('-152.701597')), blood_group='O+', website=['https://lee.com/', 'http://blackwell.com/', 'http://ramirez.com/'], username='mooreclarence', name='Jesse Sanchez', sex='M', address='619 Elizabeth Islands Apt. 065\nNorth Nicholas, MS 21317', mail='xvasquez@yahoo.com', birthdate=datetime.date(1974, 10, 31)),
#  faker_profile(job='Engineer, drilling', company='Cortez-Dickerson', ssn='106-69-4258', residence='863 Pratt Brooks Apt. 546\nLeahstad, MA 83415', current_location=(Decimal('-13.2547865'), Decimal('28.828075')), blood_group='A+', website=['http://krueger.com/', 'http://www.lozano.biz/'], username='joshuacox', name='Stephen Martin', sex='M', address='11293 Reyes Fords Apt. 081\nHeatherberg, IA 78690', mail='flevine@gmail.com', birthdate=datetime.date(1906, 7, 12)),
#  faker_profile(job='Advertising account executive', company='Carr-Patterson', ssn='749-22-0902', residence='740 Tiffany Extensions Suite 959\nThomasstad, OH 60562', current_location=(Decimal('-1.120570'), Decimal('4.019298')), blood_group='A-', website=['https://gamble.com/'], username='peggy18', name='Hannah Taylor', sex='F', address='1845 Castillo Key\nEast Stephanie, KY 82198', mail='awebb@hotmail.com', birthdate=datetime.date(1928, 10, 4)),
#  faker_profile(job='Manufacturing systems engineer', company='Mahoney-Hodge', ssn='046-43-4396', residence='36987 Lester Ridges\nSouth Christopherborough, MN 47104', current_location=(Decimal('84.675048'), Decimal('-120.772969')), blood_group='A-', website=['http://wilson-johnson.com/', 'https://fitzgerald.com/', 'https://www.nelson.info/'], username='coreygraham', name='Ann Wilson', sex='F', address='319 Payne Wall Suite 860\nMichelleburgh, MO 58418', mail='zwhite@gmail.com', birthdate=datetime.date(1988, 8, 11)),
#  faker_profile(job='Designer, industrial/product', company='Sanders, Barr and Rice', ssn='327-73-0077', residence='PSC 8589, Box 5105\nAPO AA 52075', current_location=(Decimal('-2.8615495'), Decimal('5.034633')), blood_group='O-', website=['http://turner-santos.com/', 'http://duran.biz/', 'https://cross-white.com/', 'http://www.turner.info/'], username='rebeccatorres', name='Ricky Shah', sex='M', address='USCGC Hicks\nFPO AE 23410', mail='barrjamie@hotmail.com', birthdate=datetime.date(1985, 3, 23)),
#  faker_profile(job='Banker', company='Reid LLC', ssn='609-63-3835', residence='793 Walters Drives Suite 495\nJameshaven, AL 71269', current_location=(Decimal('59.8458495'), Decimal('-162.379934')), blood_group='O+', website=['https://peters.info/', 'https://www.lewis.com/', 'http://chen.org/', 'https://www.brewer.biz/'], username='rodriguezrobert', name='Gina Hardin', sex='F', address='1102 Natalie Park\nAndrewside, WV 82821', mail='wilkinsnicole@yahoo.com', birthdate=datetime.date(1978, 11, 20)),
#  faker_profile(job='Risk analyst', company='Wilson-Boyd', ssn='031-85-8875', residence='PSC 1312, Box 4910\nAPO AA 28589', current_location=(Decimal('-65.991798'), Decimal('-103.371530')), blood_group='AB+', website=['https://mccoy-dickson.biz/', 'https://www.scott.net/', 'https://brown.com/'], username='heather35', name='Michael Aguilar', sex='M', address='USS Watson\nFPO AE 43522', mail='julia67@gmail.com', birthdate=datetime.date(2006, 6, 27)),
#  faker_profile(job='Geophysical data processor', company='Gillespie-Barton', ssn='484-39-1030', residence='53729 Jessica Vista Apt. 792\nWest Jamesfort, AZ 29030', current_location=(Decimal('-12.6681505'), Decimal('-70.929908')), blood_group='B+', website=['http://ortega.com/'], username='hallvicki', name='Edward Carpenter', sex='M', address='USNV Watson\nFPO AP 86287', mail='dawsonnicholas@yahoo.com', birthdate=datetime.date(2013, 10, 8)),
#  faker_profile(job='Dramatherapist', company='Black Group', ssn='226-53-0270', residence='855 Patrick Lane\nLoriville, SC 77103', current_location=(Decimal('50.466952'), Decimal('-3.591860')), blood_group='B-', website=['http://barr.org/', 'http://www.mcdonald.com/', 'http://mullen.com/'], username='rguerrero', name='David Allison', sex='M', address='461 Michael Mount Apt. 525\nSamanthahaven, ID 80713', mail='klittle@yahoo.com', birthdate=datetime.date(1962, 10, 11)),
#  faker_profile(job='Glass blower/designer', company='Wilson-Craig', ssn='174-90-9852', residence='11237 Sullivan Orchard Suite 027\nEast Ericton, KS 97840', current_location=(Decimal('-89.9068085'), Decimal('-145.203291')), blood_group='O-', website=['http://hodges.com/'], username='gmitchell', name='Amy Ramirez', sex='F', address='293 Warren Track Apt. 684\nPetersonmouth, NY 21090', mail='qsmith@yahoo.com', birthdate=datetime.date(1959, 7, 6)),
#  faker_profile(job='Furniture designer', company='Phillips-Velez', ssn='850-09-1062', residence='257 Rosales Corners Suite 546\nAlexisville, UT 32351', current_location=(Decimal('-65.953812'), Decimal('114.489473')), blood_group='O-', website=['http://www.ramsey.info/'], username='qking', name='Deborah Pearson', sex='F', address='25286 Nelson Wall\nSouth Masonport, MI 45125', mail='lisa11@yahoo.com', birthdate=datetime.date(1973, 4, 10)),
#  faker_profile(job='Artist', company='Brown, Burke and Potts', ssn='610-68-3277', residence='25562 Melinda Circles\nKirkbury, MT 19460', current_location=(Decimal('5.7568695'), Decimal('160.786516')), blood_group='A+', website=['http://williams-adams.com/', 'http://elliott.com/', 'http://www.foster-kramer.com/'], username='tony01', name='Julie Davis', sex='F', address='4306 Young Drive\nPort Andrewburgh, NJ 93821', mail='erinhall@yahoo.com', birthdate=datetime.date(1944, 10, 2)),
#  faker_profile(job='Radiation protection practitioner', company='Salazar PLC', ssn='324-72-7716', residence='33133 Matthew Ranch Apt. 740\nWilliamschester, AL 10726', current_location=(Decimal('-83.544355'), Decimal('86.080966')), blood_group='A+', website=['https://miller-colon.com/', 'https://meyer.biz/', 'https://long.com/', 'http://jackson.biz/'], username='lucas21', name='Jennifer Hopkins', sex='F', address='508 Moreno Mountain Suite 749\nRebeccaberg, AR 94826', mail='pearsonkatherine@yahoo.com', birthdate=datetime.date(2005, 6, 29)),
#  faker_profile(job='Geneticist, molecular', company='Wade-Richard', ssn='646-92-2605', residence='570 Fry Union\nWest Alexanderville, NY 53179', current_location=(Decimal('-82.690740'), Decimal('-63.521013')), blood_group='O+', website=['https://duarte.com/', 'https://www.carey.net/', 'http://mayer.com/', 'https://long-jackson.com/'], username='mendozaashley', name='Darren Mccullough', sex='M', address='61128 Pratt Isle Suite 841\nPort Elizabeth, TX 80268', mail='pamela88@hotmail.com', birthdate=datetime.date(1948, 4, 16)),
#  faker_profile(job='Research officer, trade union', company='Lee PLC', ssn='529-88-2508', residence='770 Debra Passage\nRileymouth, NV 27691', current_location=(Decimal('-48.670874'), Decimal('99.781195')), blood_group='B+', website=['http://galvan.com/', 'https://www.vargas.com/', 'http://schwartz-olson.info/', 'http://www.wilson.com/'], username='feliciamays', name='Pedro Kerr', sex='M', address='14727 Smith Trace\nJonesstad, MN 14977', mail='emily83@yahoo.com', birthdate=datetime.date(1939, 1, 11)),
#  faker_profile(job='Recruitment consultant', company='Jenkins, Sanchez and Dean', ssn='726-52-6158', residence='8318 Melissa Road\nTylerport, NM 17466', current_location=(Decimal('81.9765555'), Decimal('-169.781472')), blood_group='O-', website=['https://jones-hurst.com/', 'https://madden-schwartz.net/'], username='daniellepalmer', name='Alexis Reynolds', sex='F', address='155 Tucker Mountain Suite 409\nNew Brendaland, MS 69460', mail='cookdavid@yahoo.com', birthdate=datetime.date(1979, 8, 19)),
#  faker_profile(job='Plant breeder/geneticist', company='Wilson-Wilson', ssn='736-44-2818', residence='92284 Wagner Brook\nNew Donaldmouth, IL 88951', current_location=(Decimal('65.7644815'), Decimal('179.914716')), blood_group='O+', website=['https://evans.com/'], username='dennisford', name='Tony Vaughan', sex='M', address='384 Martinez Views\nEast Amanda, MS 52651', mail='mturner@gmail.com', birthdate=datetime.date(1989, 5, 23)),
#  faker_profile(job='Plant breeder/geneticist', company='Valdez and Sons', ssn='514-90-4531', residence='4819 Ryan Overpass\nJasonbury, MA 42698', current_location=(Decimal('-31.665201'), Decimal('-16.403605')), blood_group='AB-', website=['http://rodriguez-green.net/', 'https://klein.com/', 'http://mcdaniel.net/'], username='yrodriguez', name='John Alvarado', sex='M', address='6363 Lawson Land Suite 705\nBradleyville, AR 45080', mail='sandra76@hotmail.com', birthdate=datetime.date(1996, 12, 19)),
#  faker_profile(job='Development worker, international aid', company='Wong and Sons', ssn='433-25-4828', residence='766 James Fields\nJerryview, UT 45620', current_location=(Decimal('-49.0400875'), Decimal('155.406965')), blood_group='O-', website=['https://sims.com/', 'http://hatfield-green.org/'], username='raymondcochran', name='Cassie Anderson', sex='F', address='834 Matthew Place\nElizabethport, AZ 36232', mail='tyleramanda@gmail.com', birthdate=datetime.date(1991, 4, 11)),
#  faker_profile(job='Biochemist, clinical', company='Miller, Logan and Lewis', ssn='678-14-8785', residence='89400 Nicholas Cove Apt. 795\nDarrenville, MN 30729', current_location=(Decimal('-23.953825'), Decimal('-164.575779')), blood_group='A+', website=['http://higgins.info/', 'https://www.arroyo-payne.net/', 'https://www.sanchez.biz/', 'http://robbins-gibson.biz/'], username='lauramonroe', name='John Tucker', sex='M', address='11003 Parrish Plain\nWarrenmouth, RI 09189', mail='harrisderek@gmail.com', birthdate=datetime.date(1914, 8, 11)),
#  faker_profile(job='Health service manager', company='Harrell-Russell', ssn='052-25-7480', residence='34312 Lisa Drives Suite 867\nSchaeferchester, OH 75464', current_location=(Decimal('-0.612227'), Decimal('157.304635')), blood_group='B+', website=['https://edwards.com/', 'https://www.wade-armstrong.com/', 'http://www.smith.com/'], username='hernandezchristopher', name='Mr. Joseph Scott Jr.', sex='M', address='86541 Lambert Fort Suite 806\nDavismouth, ND 66140', mail='michael46@gmail.com', birthdate=datetime.date(1988, 3, 26)),
#  faker_profile(job='Therapeutic radiographer', company='Gonzales, Foster and Ball', ssn='451-73-8254', residence='55270 Williams Trafficway\nRamoschester, NH 91210', current_location=(Decimal('-19.5058775'), Decimal('-7.779799')), blood_group='O+', website=['https://www.brown.com/', 'http://salazar.net/'], username='zgonzalez', name='Kevin Jackson', sex='M', address='64331 Wilson Harbor\nKelleyfort, NY 42298', mail='wcarrillo@yahoo.com', birthdate=datetime.date(2011, 7, 28)),
#  faker_profile(job='Heritage manager', company='Norris-Lopez', ssn='493-50-5723', residence='37370 Dawson Parkway Suite 210\nHernandezside, CA 80714', current_location=(Decimal('-88.0475145'), Decimal('146.640894')), blood_group='A-', website=['https://www.schwartz.com/', 'https://schwartz.info/', 'http://chen.com/', 'http://www.silva-roberts.com/'], username='carol65', name='Nicole Lawson', sex='F', address='1319 Kristen Forest Suite 280\nHallmouth, KS 61702', mail='fieldsscott@hotmail.com', birthdate=datetime.date(1952, 12, 20)),
#  faker_profile(job='Journalist, magazine', company='Patel-King', ssn='765-40-3193', residence='9240 Martinez Trail\nWest Bryan, WA 89702', current_location=(Decimal('-53.124373'), Decimal('125.442759')), blood_group='AB+', website=['http://key.com/', 'https://dixon.com/'], username='janice72', name='Jonathan Duncan', sex='M', address='287 Perez Springs Suite 785\nJoannemouth, SD 65284', mail='vanessa39@hotmail.com', birthdate=datetime.date(1995, 7, 11)),
#  faker_profile(job='Leisure centre manager', company='Johnson-Taylor', ssn='796-84-4226', residence='41866 Owen Center Apt. 653\nSouth Susan, ND 13011', current_location=(Decimal('41.310561'), Decimal('161.297619')), blood_group='AB-', website=['https://www.thomas-wilson.com/', 'https://taylor.org/', 'https://www.harris.com/'], username='williamsderrick', name='Aaron Smith', sex='M', address='11874 May Lake\nNorth Mauriceside, OR 05681', mail='fbrown@hotmail.com', birthdate=datetime.date(1944, 8, 4)),
#  faker_profile(job='Tax adviser', company='Jones, Cobb and Swanson', ssn='224-90-0211', residence='Unit 0835 Box 9395\nDPO AE 68724', current_location=(Decimal('-6.9669545'), Decimal('93.164139')), blood_group='O+', website=['https://becker-cisneros.org/'], username='douglascombs', name='Michele Anderson', sex='F', address='Unit 0492 Box 2850\nDPO AP 82981', mail='kelleyjason@hotmail.com', birthdate=datetime.date(1960, 7, 12)),
#  faker_profile(job='Musician', company='Carpenter, Sloan and Jenkins', ssn='597-21-8708', residence='9777 Porter Spring\nPort Evan, IL 91539', current_location=(Decimal('-67.282036'), Decimal('27.376286')), blood_group='AB+', website=['https://pena.com/'], username='thomas34', name='Joshua Gordon', sex='M', address='98135 Patrick Burgs\nNew Ruth, ID 03562', mail='jasonjohnson@yahoo.com', birthdate=datetime.date(1921, 4, 2)),
#  faker_profile(job='Town planner', company='Lynch and Sons', ssn='016-05-7570', residence='67689 Murphy Hill\nSouth Amandaville, MI 77171', current_location=(Decimal('-57.961302'), Decimal('-17.698549')), blood_group='B-', website=['https://reynolds.com/', 'https://www.sanchez.org/'], username='thompsoncarmen', name='Christopher Franklin', sex='M', address='09447 Dana Camp Apt. 055\nPort Brian, CO 36094', mail='thompsonmark@hotmail.com', birthdate=datetime.date(1956, 3, 23)),
#  faker_profile(job='Teacher, special educational needs', company='Powers, Jones and White', ssn='019-98-8114', residence='37351 Timothy Spurs\nEast Ashleybury, SC 09077', current_location=(Decimal('-84.274088'), Decimal('7.489825')), blood_group='B+', website=['https://www.davis.biz/', 'http://www.scott.com/'], username='angelawalker', name='Carol Higgins', sex='F', address='59663 Sullivan Orchard\nEast Daniel, UT 78006', mail='wjames@hotmail.com', birthdate=datetime.date(1915, 3, 23)),
#  faker_profile(job='Plant breeder/geneticist', company='Mcmahon Inc', ssn='413-75-3504', residence='USCGC Moore\nFPO AA 41576', current_location=(Decimal('21.7515325'), Decimal('-9.243045')), blood_group='A+', website=['https://compton.com/', 'https://www.hayes.com/', 'https://fuentes-zimmerman.info/'], username='paulmary', name='Cindy Ritter', sex='F', address='035 Nicole Ports Apt. 851\nEast Geoffreyland, WI 96331', mail='carlos55@hotmail.com', birthdate=datetime.date(1982, 10, 27)),
#  faker_profile(job='Fine artist', company='Simon-Shea', ssn='405-52-1225', residence='564 Samantha Roads\nPaynestad, AZ 28305', current_location=(Decimal('-18.9282175'), Decimal('7.757096')), blood_group='AB-', website=['https://www.stephens.com/'], username='tamara92', name='Christina Brown', sex='F', address='357 Serrano Port\nNorth Davidtown, MA 73261', mail='dgreen@hotmail.com', birthdate=datetime.date(1942, 1, 2)),
#  faker_profile(job='Nurse, learning disability', company='Blake PLC', ssn='153-76-2889', residence='8138 Smith Loaf Suite 061\nWilliamsmouth, WY 17869', current_location=(Decimal('13.5037825'), Decimal('49.598356')), blood_group='A-', website=['http://www.thompson-coleman.com/', 'https://www.flores.com/', 'https://www.rollins.info/', 'https://yoder-fischer.com/'], username='ejenkins', name='Natalie Vaughn', sex='F', address='2510 Hernandez Spur\nTiffanystad, TN 76949', mail='nancy55@gmail.com', birthdate=datetime.date(1909, 3, 9)),
#  faker_profile(job='Hydrogeologist', company='Ponce, Fowler and Patrick', ssn='280-88-8761', residence='USS Werner\nFPO AP 33756', current_location=(Decimal('-77.7788195'), Decimal('-126.126329')), blood_group='A-', website=['http://www.vaughn-johnston.com/', 'https://www.peters.net/', 'https://fields-taylor.info/', 'http://schmidt-estrada.com/'], username='cohenthomas', name='Bryan Miller', sex='M', address='97185 Wilkins Forest\nPort Judyfort, NM 03350', mail='heather18@yahoo.com', birthdate=datetime.date(1971, 9, 19)),
#  faker_profile(job='Chief Operating Officer', company='Williams-Cox', ssn='474-20-8462', residence='440 Griffith Crossing Apt. 451\nPort Jason, CA 88508', current_location=(Decimal('-85.3351605'), Decimal('116.841682')), blood_group='O-', website=['http://www.alexander.org/'], username='kyle04', name='Barbara Stewart', sex='F', address='81022 Meyer Parkways Suite 781\nNew Jacqueline, CT 25473', mail='pmorris@gmail.com', birthdate=datetime.date(1959, 9, 10)),
#  faker_profile(job='Engineering geologist', company='Paul-Weaver', ssn='174-79-7404', residence='PSC 5008, Box 5521\nAPO AP 30858', current_location=(Decimal('-32.401954'), Decimal('48.307078')), blood_group='B+', website=['https://lee-kennedy.com/', 'https://www.monroe.net/', 'https://www.duran.com/', 'http://thomas.com/'], username='rfuller', name='Marie Mack', sex='F', address='248 Robert Village Suite 973\nNew Lisatown, WY 39179', mail='gwaters@gmail.com', birthdate=datetime.date(1983, 9, 11)),
#  faker_profile(job='Patent attorney', company='Perez PLC', ssn='868-48-0939', residence='5193 Robert Squares Suite 483\nWest Gregory, MD 68575', current_location=(Decimal('-27.498269'), Decimal('77.167596')), blood_group='A+', website=['https://www.taylor-ryan.info/', 'http://harrison.org/', 'https://www.vasquez.com/', 'http://www.paul-dickson.com/'], username='welchkatherine', name='Matthew Hughes', sex='M', address='PSC 2073, Box 7197\nAPO AP 73317', mail='jeffreygomez@hotmail.com', birthdate=datetime.date(1916, 8, 9)),
#  faker_profile(job='Chief of Staff', company='Davis, Reynolds and Johnson', ssn='325-77-9869', residence='628 Katherine Glens\nWest Samuel, MD 69788', current_location=(Decimal('26.3788355'), Decimal('60.393169')), blood_group='B-', website=['http://www.christian.net/', 'http://taylor-cooper.biz/', 'https://www.davies.com/', 'https://roth.net/'], username='wadams', name='Ronald Jones', sex='M', address='04665 Elizabeth Squares\nNew Mindyborough, MD 10185', mail='bthomas@hotmail.com', birthdate=datetime.date(1967, 11, 8)),
#  faker_profile(job='Brewing technologist', company='Brown Inc', ssn='818-14-0880', residence='4580 Miller Mill\nSouth Joelmouth, CO 26637', current_location=(Decimal('-84.4863655'), Decimal('96.982174')), blood_group='A-', website=['https://www.carr-johnson.info/', 'http://www.soto.com/'], username='mcampbell', name='Marvin Tucker', sex='M', address='59990 Sanders Camp Suite 645\nNorth Elizabeth, MT 17681', mail='ysloan@gmail.com', birthdate=datetime.date(1917, 6, 27)),
#  faker_profile(job='Copywriter, advertising', company='Kaiser, Duncan and Tran', ssn='045-15-9818', residence='7757 Jennifer Rapid Apt. 995\nBarbaramouth, ND 28702', current_location=(Decimal('-72.187313'), Decimal('-14.848144')), blood_group='AB+', website=['https://jones.net/'], username='angela06', name='Jesse Valdez', sex='M', address='813 Caleb Greens Suite 099\nNew Natalieside, KY 74037', mail='nward@yahoo.com', birthdate=datetime.date(2002, 3, 10)),
#  faker_profile(job='Therapist, nutritional', company='Lee and Sons', ssn='050-36-1536', residence='12368 Edwards Roads Apt. 670\nNorth Brian, WY 95068', current_location=(Decimal('-67.5176625'), Decimal('164.612604')), blood_group='B+', website=['https://www.schmitt-johnson.com/', 'http://gomez-guerrero.com/', 'https://williams-baker.info/'], username='julie80', name='Dominique Cruz', sex='F', address='89839 Jennifer Courts\nHarriston, MS 83170', mail='qhumphrey@hotmail.com', birthdate=datetime.date(2004, 6, 20)),
#  faker_profile(job='Ecologist', company='Lopez-Nelson', ssn='265-27-3441', residence='924 Roberto Corners\nLake Brian, AL 66435', current_location=(Decimal('75.659660'), Decimal('91.992502')), blood_group='AB-', website=['https://www.williams.info/', 'https://henry.com/', 'http://thomas.com/', 'https://www.alexander-harris.biz/'], username='kennethnelson', name='Brandon Ryan', sex='M', address='044 Bell Knoll\nTylerchester, ID 68798', mail='juan42@gmail.com', birthdate=datetime.date(1916, 9, 9)),
#  faker_profile(job='Therapist, speech and language', company='Crosby-Poole', ssn='820-06-9326', residence='7580 Christopher Trafficway Apt. 385\nLake Judy, NC 63168', current_location=(Decimal('66.675283'), Decimal('29.515735')), blood_group='A+', website=['http://kirk.net/', 'https://www.anderson-villarreal.com/'], username='xashley', name='Raymond Anderson', sex='M', address='677 Ethan Causeway\nNorth Marc, DE 60865', mail='xtorres@gmail.com', birthdate=datetime.date(1998, 7, 9)),
#  faker_profile(job='Scientist, product/process development', company='Lester, Mack and Cooke', ssn='367-22-6352', residence='PSC 0100, Box 7260\nAPO AP 18846', current_location=(Decimal('-29.695031'), Decimal('-160.047112')), blood_group='B-', website=['http://morgan-butler.com/', 'https://lara-mcknight.com/'], username='tiffanyholland', name='Desiree Davis', sex='F', address='646 Crystal Fords\nJamesmouth, OH 14441', mail='lori84@gmail.com', birthdate=datetime.date(1961, 5, 28)),
#  faker_profile(job='Geographical information systems officer', company='Hoffman, Cohen and Sullivan', ssn='658-05-0785', residence='6330 Thompson Spurs\nStephensshire, NV 94902', current_location=(Decimal('-2.4469185'), Decimal('130.654702')), blood_group='A+', website=['http://www.hernandez.com/', 'http://glass.com/', 'https://peterson.com/'], username='joneskevin', name='Jacob Lee', sex='M', address='3753 Steve Ville\nNorth Jason, KS 30482', mail='ucameron@hotmail.com', birthdate=datetime.date(1937, 9, 21)),
#  faker_profile(job='Seismic interpreter', company='Gonzales, Cannon and Zavala', ssn='331-72-7978', residence='9670 Brian Streets\nSouth Jenniferfort, LA 40286', current_location=(Decimal('-27.4075895'), Decimal('-162.259854')), blood_group='B+', website=['https://morgan-salinas.com/', 'http://www.garza.com/', 'http://www.pope.com/', 'https://gardner.com/'], username='rgolden', name='Dr. Kevin Dyer', sex='M', address='098 Johnson Brook Suite 409\nVincentshire, AZ 24144', mail='francisco87@hotmail.com', birthdate=datetime.date(1981, 10, 25)),
#  faker_profile(job='Industrial/product designer', company='Cook-Thomas', ssn='808-78-6122', residence='PSC 4205, Box 3900\nAPO AP 26995', current_location=(Decimal('43.090855'), Decimal('130.916399')), blood_group='O-', website=['http://mcdaniel.org/'], username='gamblecharles', name='Kelly Lee', sex='F', address='Unit 0631 Box 0456\nDPO AA 93808', mail='jamie27@hotmail.com', birthdate=datetime.date(1951, 3, 25)),
#  faker_profile(job='Teacher, early years/pre', company='Thompson and Sons', ssn='098-19-8210', residence='914 Olson Dam\nWongville, AR 81727', current_location=(Decimal('18.2234375'), Decimal('-39.654877')), blood_group='AB-', website=['https://sanchez.biz/'], username='ingramtravis', name='Morgan Cunningham', sex='F', address='21237 Little Lights Apt. 315\nEspinozaport, AK 67520', mail='johncrawford@gmail.com', birthdate=datetime.date(1987, 8, 4)),
#  faker_profile(job='Dancer', company='Morse PLC', ssn='509-71-8212', residence='87366 Victoria Passage Suite 909\nLake Kendra, SD 94039', current_location=(Decimal('-70.6740745'), Decimal('100.302886')), blood_group='AB+', website=['http://phillips-mills.com/', 'https://www.scott.info/', 'https://stevens.org/', 'https://mckenzie.com/'], username='maxwellsanchez', name='Becky Garcia', sex='F', address='8720 Walker Valley\nPort Jamesland, DC 32200', mail='wbennett@hotmail.com', birthdate=datetime.date(1980, 7, 3)),
#  faker_profile(job='Radiographer, diagnostic', company='Daniel-Shaw', ssn='754-94-7567', residence='361 Troy Throughway Apt. 575\nPort Michael, IN 89327', current_location=(Decimal('-19.6914905'), Decimal('109.681579')), blood_group='A+', website=['http://butler.com/', 'https://www.kim.com/', 'https://www.dalton-mullins.info/'], username='joyce07', name='Raymond Atkinson', sex='M', address='5056 Hanna Plains Apt. 227\nGarrisonborough, NY 47673', mail='nallen@yahoo.com', birthdate=datetime.date(2001, 7, 7)),
#  faker_profile(job='Higher education careers adviser', company='Rodriguez Inc', ssn='548-75-9911', residence='6911 Moore Stravenue\nNew Whitneyton, FL 02030', current_location=(Decimal('-18.3350505'), Decimal('-150.404677')), blood_group='B-', website=['https://www.henderson.com/', 'https://www.james-moreno.com/', 'https://lewis.org/', 'http://johnson.com/'], username='jbauer', name='Angela Rivera', sex='F', address='3076 John Lodge\nCraigland, NM 68693', mail='timothybrown@hotmail.com', birthdate=datetime.date(2003, 1, 15)),
#  faker_profile(job='Administrator, Civil Service', company='Mooney and Sons', ssn='683-23-6228', residence='268 Taylor Circles Apt. 117\nThompsonside, MA 08462', current_location=(Decimal('43.9216325'), Decimal('-51.847671')), blood_group='B+', website=['http://www.adkins.com/'], username='nicholas60', name='Zachary Jordan', sex='M', address='7051 Oscar Stream Suite 310\nLisaside, ND 50253', mail='daniellebauer@gmail.com', birthdate=datetime.date(1982, 9, 4)),
#  faker_profile(job='Newspaper journalist', company='Dunn-Johns', ssn='055-45-2617', residence='USCGC George\nFPO AP 66149', current_location=(Decimal('-72.6878335'), Decimal('148.913116')), blood_group='A+', website=['https://www.myers.com/'], username='billysandoval', name='Christopher Jennings', sex='M', address='3668 Monica Club\nPort Sherry, KY 10896', mail='julieflores@hotmail.com', birthdate=datetime.date(1909, 4, 2)),
#  faker_profile(job='Dance movement psychotherapist', company='Young PLC', ssn='687-52-8853', residence='829 Ronald Islands\nNew Crystal, UT 45064', current_location=(Decimal('42.017578'), Decimal('163.546139')), blood_group='A+', website=['http://www.rivera.info/', 'https://jacobs.com/'], username='psmith', name='Carol Martinez', sex='F', address='4658 Kelly Hollow Suite 903\nJasonview, IA 57115', mail='stephanie15@yahoo.com', birthdate=datetime.date(1979, 10, 7)),
#  faker_profile(job='Environmental consultant', company='Huerta-Miller', ssn='714-38-1279', residence='0504 Roger Lane\nNorth Heather, AR 18266', current_location=(Decimal('6.1825955'), Decimal('-169.618865')), blood_group='B-', website=['http://atkinson-cisneros.com/', 'https://brooks.org/'], username='carterdaniel', name='Natalie Davis', sex='F', address='80513 Riggs Plaza Apt. 305\nChristineside, OR 91304', mail='xhall@yahoo.com', birthdate=datetime.date(1986, 4, 19)),
# ...
#  faker_profile(job='Hydrogeologist', company='Powell-Anderson', ssn='695-97-1480', residence='412 Pacheco Crest Apt. 716\nLopezside, KY 27866', current_location=(Decimal('65.316213'), Decimal('-111.996302')), blood_group='O-', website=['http://www.romero.com/', 'http://martin.info/', 'http://clayton-savage.com/', 'https://www.summers.biz/'], username='bharrison', name='Charles Wilson', sex='M', address='1366 Morgan Courts\nEast Gregorymouth, AZ 32945', mail='katherine55@gmail.com', birthdate=datetime.date(1950, 10, 30)),
#  faker_profile(job='Engineer, aeronautical', company='Miller PLC', ssn='192-08-3477', residence='23107 Williams River Apt. 394\nCathymouth, NC 32803', current_location=(Decimal('31.364562'), Decimal('-110.335975')), blood_group='A+', website=['http://smith.com/', 'http://lopez-olson.com/', 'http://hudson.com/', 'https://www.owens.com/'], username='mevans', name='Dawn Howard', sex='F', address='141 Justin Parks\nLake Steven, AR 65966', mail='cmcdonald@hotmail.com', birthdate=datetime.date(1934, 9, 29)),
#  faker_profile(job='Architectural technologist', company='Robinson-White', ssn='653-36-4743', residence='3492 Miller Brook\nFrancesside, MI 58988', current_location=(Decimal('52.1073325'), Decimal('-172.521044')), blood_group='A+', website=['http://www.west.com/', 'http://www.santiago.info/', 'http://simpson.info/', 'http://romero-diaz.com/'], username='martinezcrystal', name='Christina Smith', sex='F', address='998 Manuel Creek\nWest Tracy, MD 82496', mail='cochrantara@hotmail.com', birthdate=datetime.date(2010, 1, 20)),
#  faker_profile(job='Scientist, biomedical', company='Lester LLC', ssn='841-78-6880', residence='639 Erica Cape\nWest Terri, CA 03525', current_location=(Decimal('-64.8230415'), Decimal('94.327281')), blood_group='AB-', website=['https://williams.net/', 'http://schneider-morgan.com/'], username='joseph94', name='Robert Diaz', sex='M', address='455 Sara Corner Apt. 717\nWest Vincent, OH 38791', mail='christinebarrett@hotmail.com', birthdate=datetime.date(1937, 12, 1)),
#  faker_profile(job='Youth worker', company='Gutierrez-Diaz', ssn='010-43-7096', residence='46053 Moore Overpass Suite 017\nPort Michele, MI 36992', current_location=(Decimal('34.035510'), Decimal('-146.692990')), blood_group='A+', website=['https://www.mays-ward.net/'], username='richardle', name='Veronica Jordan', sex='F', address='390 David Estate Suite 751\nLake Lauratown, OH 77446', mail='hjennings@yahoo.com', birthdate=datetime.date(2017, 11, 21)),
#  faker_profile(job='Statistician', company='Pittman Inc', ssn='467-74-2174', residence='3626 Robert Park\nEast Danielberg, NY 14957', current_location=(Decimal('-2.823755'), Decimal('-152.343026')), blood_group='B-', website=['http://www.hansen-garcia.org/', 'https://www.nichols.com/'], username='zjenkins', name='Edward Thomas', sex='M', address='28147 Stephanie Road Suite 719\nNicholastown, CT 93495', mail='rsingleton@hotmail.com', birthdate=datetime.date(1981, 3, 18)),
#  faker_profile(job='Amenity horticulturist', company='Knight Ltd', ssn='330-66-5600', residence='809 Sandoval Fords Suite 463\nNew Katherineton, DE 62967', current_location=(Decimal('87.9629035'), Decimal('19.572970')), blood_group='AB-', website=['https://miller.com/'], username='ricky65', name='Robert Harris', sex='M', address='78151 Alejandro Divide\nFoxmouth, AZ 42296', mail='chavezlinda@gmail.com', birthdate=datetime.date(1997, 8, 20)),
#  faker_profile(job='Broadcast journalist', company='Torres LLC', ssn='733-66-9752', residence='262 Loretta Tunnel Suite 800\nEast Tylerville, KY 46292', current_location=(Decimal('58.878762'), Decimal('-83.093474')), blood_group='A+', website=['http://lopez-contreras.org/', 'http://www.frye.com/', 'http://garcia-kelley.net/'], username='prattstephen', name='James Bradley', sex='M', address='48917 Bruce Shoal\nPort Elizabeth, TX 81830', mail='kgarcia@gmail.com', birthdate=datetime.date(1952, 5, 12)),
#  faker_profile(job='Engineering geologist', company='Thompson-Eaton', ssn='078-59-6099', residence='55239 Walker Trafficway Suite 149\nSouth Tammy, UT 13806', current_location=(Decimal('81.042547'), Decimal('140.314348')), blood_group='B+', website=['https://webb.biz/'], username='ewillis', name='Bridget Smith', sex='F', address='5043 Moyer Pass\nLorihaven, MT 55207', mail='zachary08@gmail.com', birthdate=datetime.date(1987, 5, 29)),
#  faker_profile(job='Personal assistant', company='Williams, Wheeler and Morrow', ssn='210-14-3318', residence='248 John Skyway\nPort Jacquelinemouth, CT 37842', current_location=(Decimal('76.938933'), Decimal('-152.038719')), blood_group='A+', website=['http://campbell-anderson.biz/', 'http://www.king-lewis.info/', 'http://matthews.com/', 'https://malone.biz/'], username='josephhamilton', name='Alexis Brewer', sex='F', address='6376 Eric Ways\nSouth Warrenbury, NC 17115', mail='tcooper@hotmail.com', birthdate=datetime.date(1988, 10, 26)),
#  faker_profile(job='Programmer, applications', company='Young LLC', ssn='272-64-1642', residence='5703 Jimenez Summit Suite 581\nJenniferside, CT 01387', current_location=(Decimal('79.6998715'), Decimal('38.529860')), blood_group='O+', website=['https://mcdowell.biz/', 'http://www.bryant-edwards.com/', 'https://davis.info/'], username='kherman', name='Jeffrey Ross', sex='M', address='019 Wendy Shoal\nSouth Angelafort, OR 93275', mail='medinajason@yahoo.com', birthdate=datetime.date(1928, 1, 13)),
#  faker_profile(job='Licensed conveyancer', company='Newton-Solis', ssn='387-35-7853', residence='6640 Ashley Square\nLaurahaven, MS 63968', current_location=(Decimal('50.223927'), Decimal('106.511075')), blood_group='B+', website=['https://www.spencer-evans.org/', 'http://lawrence.info/'], username='jacobdavis', name='Richard Luna V', sex='M', address='8203 Wilson Well\nNorth Carol, ND 22200', mail='tkirk@gmail.com', birthdate=datetime.date(1979, 3, 9)),
#  faker_profile(job='IT consultant', company='Carpenter-Wang', ssn='105-89-7461', residence='5969 Christopher Trace Suite 851\nLake Diana, SD 48256', current_location=(Decimal('-76.2475735'), Decimal('131.002943')), blood_group='B-', website=['https://www.park.org/'], username='jacquelinemiller', name='Margaret Barber', sex='F', address='USNS Jenkins\nFPO AP 79889', mail='christopher83@hotmail.com', birthdate=datetime.date(1930, 8, 20)),
#  faker_profile(job='Health visitor', company='Grant Inc', ssn='838-44-4079', residence='14202 Jeffrey Crossing Suite 297\nPowellshire, LA 75745', current_location=(Decimal('59.553311'), Decimal('-21.059060')), blood_group='A-', website=['http://www.morton.biz/', 'http://www.maxwell.com/'], username='kelly51', name='Brandi Carlson', sex='F', address='356 Steven Village\nNorth Denise, TN 65665', mail='priceamanda@gmail.com', birthdate=datetime.date(1961, 7, 22)),
#  faker_profile(job='Theatre manager', company='Monroe-Moon', ssn='357-54-7626', residence='1580 Annette Parkway\nLake Shannon, RI 32815', current_location=(Decimal('19.336277'), Decimal('-78.110813')), blood_group='A-', website=['http://martinez.org/', 'https://www.simmons-coleman.com/', 'http://conner.com/'], username='amanda57', name='Tyler Moore', sex='M', address='904 Ronald Plain\nEast John, AK 21221', mail='hughesdennis@yahoo.com', birthdate=datetime.date(2010, 10, 27)),
#  faker_profile(job='Contracting civil engineer', company='Forbes-Leonard', ssn='099-16-9607', residence='534 William Falls Apt. 621\nVillaton, NE 94191', current_location=(Decimal('87.312197'), Decimal('74.686406')), blood_group='A-', website=['https://www.morse-smith.com/', 'http://zhang.com/', 'https://navarro.com/'], username='valdezolivia', name='Christopher Hernandez', sex='M', address='8765 Derek Island\nNew Maria, NM 46340', mail='ann46@hotmail.com', birthdate=datetime.date(2018, 11, 29)),
#  faker_profile(job='Therapeutic radiographer', company='Monroe-Brown', ssn='711-19-2590', residence='86781 Kyle Road Apt. 941\nEast Thomas, HI 57421', current_location=(Decimal('73.237897'), Decimal('-152.322759')), blood_group='B+', website=['http://vincent-fox.com/', 'http://www.ruiz.org/'], username='nnewman', name='Ellen Mendoza', sex='F', address='4616 King Crossing Apt. 087\nNorth Nicolebury, VA 32361', mail='brittany26@yahoo.com', birthdate=datetime.date(1919, 6, 21)),
#  faker_profile(job='Further education lecturer', company='Anderson PLC', ssn='249-56-8683', residence='8107 Debbie Bypass\nPort Patty, ND 83246', current_location=(Decimal('50.7644515'), Decimal('39.771168')), blood_group='B+', website=['http://willis.com/', 'https://roberts.org/', 'http://www.mendoza-johnson.com/', 'https://www.simmons-torres.com/'], username='heather52', name='Gerald Brown', sex='M', address='01216 Richardson Run Apt. 750\nNew Dustin, VA 86337', mail='davismatthew@hotmail.com', birthdate=datetime.date(1995, 10, 26)),
#  faker_profile(job="Politician's assistant", company='Wright-Jones', ssn='688-57-2629', residence='226 Cameron Tunnel Suite 781\nTiffanyfort, MN 88551', current_location=(Decimal('41.9346555'), Decimal('103.194348')), blood_group='A+', website=['http://www.jones.com/', 'http://reese.com/', 'https://coleman-meyer.com/'], username='brucebarker', name='Jessica Strong', sex='F', address='74768 Gene Alley Apt. 708\nJohnsonland, ME 35792', mail='qmitchell@hotmail.com', birthdate=datetime.date(1927, 6, 3)),
#  faker_profile(job='Production manager', company='Pierce-Campbell', ssn='270-31-7674', residence='491 Ryan Heights\nEast Edward, ND 97708', current_location=(Decimal('71.1393525'), Decimal('-162.815976')), blood_group='B+', website=['http://sanchez.com/'], username='kimberlyhanson', name='Richard Kennedy', sex='M', address='8515 Neal Plaza\nGreenmouth, IL 78574', mail='astevens@hotmail.com', birthdate=datetime.date(1913, 9, 18)),
#  faker_profile(job='Editor, magazine features', company='Booth and Sons', ssn='253-33-5266', residence='392 Miller Rapids\nRichardstad, IL 67398', current_location=(Decimal('-45.1820275'), Decimal('-49.467801')), blood_group='B+', website=['https://www.welch.com/'], username='anna31', name='Vicki Vaughn', sex='F', address='Unit 1615 Box 0823\nDPO AA 43388', mail='kmoore@hotmail.com', birthdate=datetime.date(1979, 5, 30)),
#  faker_profile(job='Oceanographer', company='Wheeler and Sons', ssn='807-35-9407', residence='40741 Eric Passage\nLake Cory, MD 17188', current_location=(Decimal('29.1321685'), Decimal('54.745715')), blood_group='A+', website=['http://www.lane-bates.com/', 'https://www.smith.info/', 'https://flores.com/', 'http://www.mitchell.org/'], username='fcollins', name='Christopher Hunt', sex='M', address='232 Victoria Fields\nLake Leonmouth, VT 96128', mail='qrobles@yahoo.com', birthdate=datetime.date(1950, 7, 30)),
#  faker_profile(job='Solicitor', company='Singleton, Odonnell and Lee', ssn='703-86-4291', residence='PSC 0225, Box 4718\nAPO AE 41208', current_location=(Decimal('-59.3575985'), Decimal('-157.720063')), blood_group='O+', website=['http://santiago.org/', 'https://www.morrison.biz/', 'http://www.price-buchanan.com/', 'http://hunt.com/'], username='ucardenas', name='Whitney Carney', sex='F', address='81116 Timothy Squares\nLake Laurenfurt, HI 46336', mail='christopherwolf@yahoo.com', birthdate=datetime.date(2015, 7, 6)),
#  faker_profile(job='Speech and language therapist', company='Barker, Ho and Baker', ssn='142-89-7785', residence='PSC 4858, Box 5210\nAPO AA 55481', current_location=(Decimal('9.2437865'), Decimal('-118.965103')), blood_group='B-', website=['http://davis.info/', 'https://hardy-bell.com/', 'https://www.mullen.info/'], username='erinvalentine', name='Thomas Collins', sex='M', address='5949 Page Island\nWest Jenniferport, GA 92384', mail='daniel10@yahoo.com', birthdate=datetime.date(1947, 3, 15)),
#  faker_profile(job='Landscape architect', company='Perry-Kelly', ssn='157-61-5488', residence='8987 Sanchez Brook\nNicholaston, NH 99475', current_location=(Decimal('-32.420015'), Decimal('163.375517')), blood_group='B-', website=['http://bullock.net/', 'http://riley-miller.info/'], username='staffordjamie', name='Melissa Gill', sex='F', address='81178 Travis Trail\nWest Paigemouth, DC 77739', mail='ahansen@gmail.com', birthdate=datetime.date(2016, 3, 17)),
#  faker_profile(job='Broadcast journalist', company='Miller, Sanchez and Sanchez', ssn='009-57-8660', residence='USS Jones\nFPO AE 49180', current_location=(Decimal('-78.4790635'), Decimal('-47.799711')), blood_group='AB+', website=['https://www.bautista.org/', 'https://www.vasquez.com/'], username='spotter', name='Yvonne Carney', sex='F', address='252 Davis Loaf Suite 648\nEast Timothy, WY 54104', mail='danielsnow@hotmail.com', birthdate=datetime.date(1978, 5, 4)),
#  faker_profile(job='Secretary, company', company='Massey-Hale', ssn='747-80-8252', residence='PSC 5586, Box 7191\nAPO AP 77202', current_location=(Decimal('0.9113825'), Decimal('-38.739393')), blood_group='O+', website=['https://www.sellers.com/'], username='emily32', name='Crystal Peterson', sex='F', address='44023 Amanda Drives\nSmithland, ME 22618', mail='davislori@hotmail.com', birthdate=datetime.date(2004, 1, 24)),
#  faker_profile(job='Editor, commissioning', company='Morgan, King and Moore', ssn='118-53-7332', residence='594 Elizabeth Knolls\nNorth Jamesborough, RI 34377', current_location=(Decimal('19.3019605'), Decimal('176.833287')), blood_group='AB-', website=['http://davis.com/', 'http://www.hall.net/', 'https://johnson.com/'], username='josemcdonald', name='Nicole Gonzales', sex='F', address='9726 Edward Stravenue Suite 255\nLorichester, NV 55436', mail='charlenecoleman@gmail.com', birthdate=datetime.date(2007, 10, 14)),
#  faker_profile(job='Health and safety inspector', company='Wolfe, Smith and Smith', ssn='187-94-0119', residence='378 Michael Square\nAngelaside, NV 66203', current_location=(Decimal('73.214895'), Decimal('138.720469')), blood_group='O+', website=['https://www.young.com/', 'http://www.elliott.org/', 'https://cook.com/'], username='hicksdeborah', name='Selena Sampson', sex='F', address='98260 Campbell Lodge\nRussellport, IN 96557', mail='xpeterson@hotmail.com', birthdate=datetime.date(1976, 6, 20)),
#  faker_profile(job='Pathologist', company='Calhoun PLC', ssn='501-81-6896', residence='14796 Green Junction\nPennychester, FL 78442', current_location=(Decimal('9.838043'), Decimal('68.304774')), blood_group='AB-', website=['http://www.sullivan.net/'], username='bsanchez', name='Miss Sara Rocha', sex='F', address='USNV Brooks\nFPO AA 48490', mail='smithsamantha@gmail.com', birthdate=datetime.date(1935, 6, 13)),
#  faker_profile(job='Editor, commissioning', company='Cooper, Garcia and Smith', ssn='107-67-4347', residence='30883 Anderson Rapids\nBrowntown, SD 09425', current_location=(Decimal('4.9594825'), Decimal('44.930028')), blood_group='A+', website=['https://ortiz.com/', 'http://carter-cannon.com/', 'http://www.mendoza.info/'], username='jamesmoore', name='Matthew Pena', sex='M', address='69673 Michael Hollow Suite 259\nEast Markville, AR 83759', mail='douglas47@gmail.com', birthdate=datetime.date(1916, 3, 24)),
#  faker_profile(job='Administrator', company='Gray-Ellison', ssn='714-96-0648', residence='5811 Chavez Walks\nHendersonmouth, WA 12882', current_location=(Decimal('-8.3419925'), Decimal('90.016275')), blood_group='A-', website=['https://www.sanchez-robinson.info/', 'https://www.ramirez.com/'], username='david13', name='Paul Trevino', sex='M', address='476 Brooke Ville Suite 772\nEast Sarah, KY 71643', mail='fowlerchristopher@yahoo.com', birthdate=datetime.date(1966, 9, 8)),
#  ...]

# %%
def calculate():
    '''
    This function calculates the maximum blood_group, average current location, oldest person age and average age
    '''
    import datetime
    from datetime import date
    group = {}
    loc_coordinates = [0,0]
    max_age = {'age': 0, 'profile': None}
    avg_age = 0
    calc_dob = ()
    date_today = datetime.date.today()
    bg=fake_profile()
    for i in bg:
        group[i.blood_group]= group.get(i.blood_group,0) + 1
        loc_coordinates[0]+=(i.current_location[0]/10000)
        loc_coordinates[1]+=(i.current_location[1]/10000)
        #age = (datetime.date.today() - i.birthdate).days
        #print(age)
        age = (date_today - i.birthdate).days
        if  age > max_age['age']:
            max_age['age'] = age
            max_age['profile'] = i
        avg_age += int(age/365)

        #print(dt - age[i.birthdate])
    print(avg_age)
    print(max(group))
    print(loc_coordinates)

calculate()
# Out:
# 0:00:17.381551
# 580557
# O-
# [Decimal('-0.62639445820'), Decimal('0.8515113305')]

# %%
d = []
def fake_profile_dict():
    '''
    This function is used to generate 10000 profiles using the faker module in python
    It stores all this data in dictionary
    '''
    start = datetime.now()
    for i in range(10000):
        d.append(fake.profile())
    
    end = datetime.now()
    print(end-start)
    return d
fake_profile_dict()
# Out:
# 0:00:14.104998
# [{'address': '13001 Wagner Brook Suite 141\nEast Paulland, MN 46792',
#   'birthdate': datetime.date(2011, 6, 29),
#   'blood_group': 'O+',
#   'company': 'Prince, Robertson and Douglas',
#   'current_location': (Decimal('26.985993'), Decimal('-98.000133')),
#   'job': 'Structural engineer',
#   'mail': 'jimmy82@yahoo.com',
#   'name': 'Jessica Guzman',
#   'residence': '94559 Duran Run Suite 093\nDuncanport, CT 59350',
#   'sex': 'F',
#   'ssn': '725-07-2196',
#   'username': 'nthompson',
#   'website': ['http://george.biz/',
#    'https://www.burns.org/',
#    'https://www.taylor.info/',
#    'https://ruiz.info/']},
#  {'address': 'USCGC Berg\nFPO AA 04614',
#   'birthdate': datetime.date(1927, 9, 6),
#   'blood_group': 'A+',
#   'company': 'Lindsey, Stein and White',
#   'current_location': (Decimal('15.949950'), Decimal('108.808635')),
#   'job': 'Surveyor, quantity',
#   'mail': 'john78@yahoo.com',
#   'name': 'Catherine Lee',
#   'residence': '422 David Valleys\nPattersonfurt, CA 63596',
#   'sex': 'F',
#   'ssn': '688-42-1071',
#   'username': 'gatescynthia',
#   'website': ['https://www.dean.biz/',
#    'http://arnold.com/',
#    'https://lopez-richardson.com/',
#    'https://salazar.net/']},
#  {'address': '6266 Mary Points\nThomasmouth, AL 36156',
#   'birthdate': datetime.date(1986, 10, 8),
#   'blood_group': 'A-',
#   'company': 'Salinas LLC',
#   'current_location': (Decimal('40.441816'), Decimal('-129.691472')),
#   'job': 'Learning disability nurse',
#   'mail': 'berrypaige@hotmail.com',
#   'name': 'Roger Ford',
#   'residence': '2922 Lopez Trail\nWest Robertshire, FL 69455',
#   'sex': 'M',
#   'ssn': '631-08-8649',
#   'username': 'vbrown',
#   'website': ['https://smith-robertson.com/',
#    'http://thornton.com/',
#    'https://morris.net/']},
#  {'address': 'PSC 8599, Box 7015\nAPO AP 90255',
#   'birthdate': datetime.date(1918, 11, 26),
#   'blood_group': 'O+',
#   'company': 'Torres-Thompson',
#   'current_location': (Decimal('-80.558230'), Decimal('-91.339389')),
#   'job': 'Ergonomist',
#   'mail': 'ewilson@gmail.com',
#   'name': 'Emily Taylor',
#   'residence': '84215 Jessica Cliffs\nEast Matthewville, CO 61716',
#   'sex': 'F',
#   'ssn': '610-56-0894',
#   'username': 'hoodcynthia',
#   'website': ['http://cruz-mendoza.com/']},
#  {'address': '01800 Jonathan Dam\nWallsbury, WY 49500',
#   'birthdate': datetime.date(2018, 10, 22),
#   'blood_group': 'A+',
#   'company': 'Waller-Shelton',
#   'current_location': (Decimal('-37.184990'), Decimal('123.029191')),
#   'job': 'Diplomatic Services operational officer',
#   'mail': 'kevinyoung@hotmail.com',
#   'name': 'Beth Kelley',
#   'residence': '950 Aguilar River Suite 352\nNguyenfort, AZ 12697',
#   'sex': 'F',
#   'ssn': '746-13-7848',
#   'username': 'deniseschmidt',
#   'website': ['https://house.biz/', 'http://www.russell.info/']},
#  {'address': '4385 Morgan Vista\nSouth Elizabethbury, CO 64424',
#   'birthdate': datetime.date(2010, 8, 16),
#   'blood_group': 'AB-',
#   'company': 'Davis Inc',
#   'current_location': (Decimal('26.063089'), Decimal('136.897011')),
#   'job': 'Information systems manager',
#   'mail': 'tcrawford@hotmail.com',
#   'name': 'Amy Richards',
#   'residence': '56416 Steven Curve\nNorth Scottton, SC 83849',
#   'sex': 'F',
#   'ssn': '187-04-2640',
#   'username': 'gsmith',
#   'website': ['https://williams-holmes.net/']},
#  {'address': '74471 Vang Road\nStephenview, WY 40098',
#   'birthdate': datetime.date(1922, 10, 11),
#   'blood_group': 'B-',
#   'company': 'Graves-Mcgee',
#   'current_location': (Decimal('-32.216438'), Decimal('-114.087187')),
#   'job': 'Interpreter',
#   'mail': 'bsimpson@hotmail.com',
#   'name': 'Taylor Simmons',
#   'residence': '63518 Mitchell Union\nPort James, VA 17332',
#   'sex': 'M',
#   'ssn': '371-70-6515',
#   'username': 'anna57',
#   'website': ['http://www.burton.info/',
#    'https://www.page-arellano.com/',
#    'http://www.duncan.com/',
#    'https://bray.com/']},
#  {'address': '59033 Samuel Brooks Suite 112\nLake Ricky, GA 22724',
#   'birthdate': datetime.date(1994, 2, 11),
#   'blood_group': 'AB-',
#   'company': 'Hebert-Moran',
#   'current_location': (Decimal('67.8418755'), Decimal('-43.202724')),
#   'job': 'Stage manager',
#   'mail': 'keith04@yahoo.com',
#   'name': 'Pamela Rubio',
#   'residence': '637 Galloway Glens Apt. 241\nDurhamview, OH 33505',
#   'sex': 'F',
#   'ssn': '514-18-0569',
#   'username': 'osbornerachel',
#   'website': ['http://wilson.com/', 'https://www.cook.net/']},
#  {'address': '9641 Choi Path\nCollinmouth, DE 40494',
#   'birthdate': datetime.date(2012, 4, 1),
#   'blood_group': 'A-',
#   'company': 'Harrison LLC',
#   'current_location': (Decimal('-80.5884615'), Decimal('-95.772111')),
#   'job': 'Geoscientist',
#   'mail': 'dianakelly@yahoo.com',
#   'name': 'Robert Petersen',
#   'residence': '590 Kendra Shoal Suite 608\nChristopherstad, NE 99223',
#   'sex': 'M',
#   'ssn': '724-72-5354',
#   'username': 'kimberlybowman',
#   'website': ['https://berry-shepherd.com/', 'https://www.johnson.com/']},
#  {'address': '967 Billy Flats\nKennethside, VA 55674',
#   'birthdate': datetime.date(1916, 8, 17),
#   'blood_group': 'A+',
#   'company': 'Jimenez-Riley',
#   'current_location': (Decimal('-53.2422315'), Decimal('169.424225')),
#   'job': 'Science writer',
#   'mail': 'aimee82@yahoo.com',
#   'name': 'Timothy Thomas',
#   'residence': '098 Forbes Manors\nNew Jonathanport, NH 97124',
#   'sex': 'M',
#   'ssn': '405-41-1540',
#   'username': 'ninaabbott',
#   'website': ['http://ramos.com/',
#    'http://www.butler.com/',
#    'http://www.bradley-hernandez.biz/']},
#  {'address': '02761 Jones Villages Suite 058\nSouth Erica, TX 27213',
#   'birthdate': datetime.date(1980, 7, 30),
#   'blood_group': 'B+',
#   'company': 'Casey PLC',
#   'current_location': (Decimal('67.873643'), Decimal('-97.825269')),
#   'job': 'Radio producer',
#   'mail': 'karigordon@yahoo.com',
#   'name': 'Jesse Logan',
#   'residence': '47408 Warner Lane Apt. 902\nNew Alexis, AR 53433',
#   'sex': 'M',
#   'ssn': '336-49-7363',
#   'username': 'qroberts',
#   'website': ['https://www.lopez.com/',
#    'http://smith.org/',
#    'http://www.house-miller.com/']},
#  {'address': '9777 Hines Village\nNorth Gary, MA 18216',
#   'birthdate': datetime.date(1944, 11, 20),
#   'blood_group': 'O+',
#   'company': 'Kim-Berry',
#   'current_location': (Decimal('-68.203900'), Decimal('42.564854')),
#   'job': 'Facilities manager',
#   'mail': 'hughestrevor@gmail.com',
#   'name': 'Taylor Copeland',
#   'residence': '6638 Rachael Divide Apt. 792\nLake Cameron, MD 80867',
#   'sex': 'F',
#   'ssn': '181-58-2222',
#   'username': 'gonzalezjoshua',
#   'website': ['http://ramirez.biz/',
#    'http://www.love-wilson.info/',
#    'http://johnson.com/',
#    'http://waller-johnson.com/']},
#  {'address': '68058 Benjamin Meadow\nBlairtown, SD 26292',
#   'birthdate': datetime.date(1982, 2, 15),
#   'blood_group': 'B-',
#   'company': 'Thomas-Hall',
#   'current_location': (Decimal('-30.753675'), Decimal('94.566980')),
#   'job': 'Careers adviser',
#   'mail': 'doris49@hotmail.com',
#   'name': 'Laura Potts',
#   'residence': '4525 Colon Causeway\nEast Ruthside, VT 08566',
#   'sex': 'F',
#   'ssn': '555-86-4040',
#   'username': 'charlesgreen',
#   'website': ['http://www.ross-brown.net/', 'https://vargas.com/']},
#  {'address': '931 Carolyn Wall\nNorth Williammouth, OH 63197',
#   'birthdate': datetime.date(1985, 1, 16),
#   'blood_group': 'B-',
#   'company': 'Ross, Johnson and Johnson',
#   'current_location': (Decimal('4.911783'), Decimal('160.453245')),
#   'job': 'Land/geomatics surveyor',
#   'mail': 'zbrown@yahoo.com',
#   'name': 'Clarence Edwards',
#   'residence': '99975 Gregory Squares\nTrevorhaven, GA 66241',
#   'sex': 'M',
#   'ssn': '436-25-9072',
#   'username': 'jenkinsjeffrey',
#   'website': ['http://burns.net/', 'https://www.watson-sandoval.info/']},
#  {'address': '456 Christopher Courts\nNorth Richard, AL 90395',
#   'birthdate': datetime.date(1990, 1, 7),
#   'blood_group': 'O+',
#   'company': 'Bowman, Nicholson and Bell',
#   'current_location': (Decimal('-33.9776385'), Decimal('7.544045')),
#   'job': 'Waste management officer',
#   'mail': 'ksmith@yahoo.com',
#   'name': 'Ian Walker',
#   'residence': '59666 Martin Inlet Apt. 333\nEast Kevin, DC 45843',
#   'sex': 'M',
#   'ssn': '881-89-0311',
#   'username': 'shawnlloyd',
#   'website': ['https://www.keller.net/',
#    'https://campbell.com/',
#    'https://www.castaneda.info/']},
#  {'address': '74050 Stark Islands Suite 274\nChandlerhaven, GA 62118',
#   'birthdate': datetime.date(1949, 4, 27),
#   'blood_group': 'A+',
#   'company': 'Jones, Hernandez and Phillips',
#   'current_location': (Decimal('41.533797'), Decimal('-160.349675')),
#   'job': 'Ranger/warden',
#   'mail': 'xforbes@yahoo.com',
#   'name': 'Tina Vaughn',
#   'residence': '297 Oliver Estate\nRickfort, NC 81173',
#   'sex': 'F',
#   'ssn': '291-02-8373',
#   'username': 'micheal32',
#   'website': ['https://www.ward-brady.com/', 'https://www.rogers-hines.net/']},
#  {'address': '401 Smith Ramp Apt. 357\nClarkton, ID 53739',
#   'birthdate': datetime.date(1989, 1, 27),
#   'blood_group': 'A+',
#   'company': 'Allen-Patton',
#   'current_location': (Decimal('61.321957'), Decimal('175.575118')),
#   'job': 'Financial controller',
#   'mail': 'jonathanabbott@hotmail.com',
#   'name': 'Mary Reynolds',
#   'residence': '6911 Crystal Course\nNorth Michael, TN 35938',
#   'sex': 'F',
#   'ssn': '781-74-4394',
#   'username': 'kelly18',
#   'website': ['http://jacobs.biz/']},
#  {'address': '09314 Emma Mission\nChristineland, HI 24342',
#   'birthdate': datetime.date(1926, 9, 6),
#   'blood_group': 'AB-',
#   'company': 'Hudson PLC',
#   'current_location': (Decimal('19.875955'), Decimal('-0.349702')),
#   'job': 'Furniture conservator/restorer',
#   'mail': 'brownmichelle@gmail.com',
#   'name': 'Denise Fields',
#   'residence': '64054 Martin Stravenue\nPort Katherineshire, CA 26744',
#   'sex': 'F',
#   'ssn': '124-06-5731',
#   'username': 'rebecca52',
#   'website': ['https://www.barber.com/']},
#  {'address': '5445 Smith Loaf Suite 978\nEast Margaret, AZ 85591',
#   'birthdate': datetime.date(1998, 11, 27),
#   'blood_group': 'AB+',
#   'company': 'Garcia Group',
#   'current_location': (Decimal('-3.273825'), Decimal('-83.036827')),
#   'job': 'Scientific laboratory technician',
#   'mail': 'timothy35@hotmail.com',
#   'name': 'Stephen Lyons',
#   'residence': '234 Black Meadows\nAngelamouth, HI 86158',
#   'sex': 'M',
#   'ssn': '284-30-3368',
#   'username': 'youngsandra',
#   'website': ['https://macdonald.org/']},
#  {'address': '2614 Harris Ports Apt. 016\nEast Amanda, HI 02357',
#   'birthdate': datetime.date(1979, 3, 30),
#   'blood_group': 'B+',
#   'company': 'Reyes Inc',
#   'current_location': (Decimal('9.323480'), Decimal('-107.087520')),
#   'job': 'Information officer',
#   'mail': 'steven61@yahoo.com',
#   'name': 'Eric Russell',
#   'residence': 'USCGC Mason\nFPO AP 95144',
#   'sex': 'M',
#   'ssn': '323-05-4527',
#   'username': 'cclark',
#   'website': ['https://dunn.com/', 'http://stewart-mendez.com/']},
#  {'address': '6066 Kathryn Oval\nLake Phillipborough, RI 82213',
#   'birthdate': datetime.date(2009, 5, 29),
#   'blood_group': 'AB-',
#   'company': 'White, Smith and Jenkins',
#   'current_location': (Decimal('40.7133095'), Decimal('-170.636129')),
#   'job': 'Arts administrator',
#   'mail': 'james15@hotmail.com',
#   'name': 'Patrick Turner',
#   'residence': 'PSC 0697, Box 5343\nAPO AA 71452',
#   'sex': 'M',
#   'ssn': '079-07-5066',
#   'username': 'garzabrett',
#   'website': ['https://www.hatfield.com/']},
#  {'address': '643 Mary Manor Suite 005\nMelanieview, SD 73209',
#   'birthdate': datetime.date(1911, 4, 7),
#   'blood_group': 'O-',
#   'company': 'Brown PLC',
#   'current_location': (Decimal('-73.0530105'), Decimal('75.022584')),
#   'job': 'Freight forwarder',
#   'mail': 'markswanson@yahoo.com',
#   'name': 'Joseph Wagner',
#   'residence': '825 Timothy Plain Suite 337\nPamelafurt, AK 70091',
#   'sex': 'M',
#   'ssn': '450-01-3128',
#   'username': 'bhanson',
#   'website': ['https://www.jones.com/',
#    'https://moore-erickson.org/',
#    'http://vargas-wilcox.com/']},
#  {'address': '3649 Hall Alley Suite 789\nKelleymouth, WY 54054',
#   'birthdate': datetime.date(1922, 1, 19),
#   'blood_group': 'O-',
#   'company': 'Dawson and Sons',
#   'current_location': (Decimal('-26.8061415'), Decimal('-67.824405')),
#   'job': 'Cabin crew',
#   'mail': 'odonnellamanda@gmail.com',
#   'name': 'Brian Collins',
#   'residence': 'PSC 9480, Box 9559\nAPO AP 63190',
#   'sex': 'M',
#   'ssn': '613-60-6822',
#   'username': 'carterkyle',
#   'website': ['https://www.moon.com/', 'http://scott.info/']},
#  {'address': '52301 Anderson Bridge\nRichardbury, HI 70663',
#   'birthdate': datetime.date(1987, 2, 16),
#   'blood_group': 'A+',
#   'company': 'Carter Inc',
#   'current_location': (Decimal('59.8900915'), Decimal('163.594111')),
#   'job': 'Bonds trader',
#   'mail': 'bgood@hotmail.com',
#   'name': 'Robert Fields',
#   'residence': '3709 Sheryl Burg Suite 052\nEast Barbara, GA 88619',
#   'sex': 'M',
#   'ssn': '052-94-4194',
#   'username': 'martha51',
#   'website': ['http://www.hansen.com/',
#    'http://green.com/',
#    'https://www.sweeney.com/']},
#  {'address': '818 James Gardens Suite 480\nWilsonhaven, UT 85422',
#   'birthdate': datetime.date(1921, 10, 24),
#   'blood_group': 'O+',
#   'company': 'Cooper, Francis and Krause',
#   'current_location': (Decimal('-60.383995'), Decimal('-111.135419')),
#   'job': 'Research scientist (medical)',
#   'mail': 'anthonykimberly@hotmail.com',
#   'name': 'Ashley Brown',
#   'residence': '6447 Smith Underpass\nSanchezville, LA 13303',
#   'sex': 'F',
#   'ssn': '669-17-1567',
#   'username': 'david72',
#   'website': ['https://www.norris.com/',
#    'http://george.org/',
#    'https://carter-james.com/',
#    'https://savage.com/']},
#  {'address': '82444 Frederick Road\nGarrisonville, WI 92696',
#   'birthdate': datetime.date(1981, 2, 25),
#   'blood_group': 'A+',
#   'company': 'Jenkins PLC',
#   'current_location': (Decimal('-29.236683'), Decimal('-2.590977')),
#   'job': 'Consulting civil engineer',
#   'mail': 'kathleen98@yahoo.com',
#   'name': 'Mia Smith',
#   'residence': '85336 Jones Divide Apt. 873\nLake Michelle, NY 64150',
#   'sex': 'F',
#   'ssn': '185-41-4806',
#   'username': 'qrivers',
#   'website': ['https://www.watts.com/']},
#  {'address': '8371 Jennifer Cape\nPerrytown, IN 60698',
#   'birthdate': datetime.date(1958, 3, 10),
#   'blood_group': 'AB-',
#   'company': 'Walker-Richardson',
#   'current_location': (Decimal('49.480012'), Decimal('156.199683')),
#   'job': 'Multimedia specialist',
#   'mail': 'williamdavila@gmail.com',
#   'name': 'Paul Ortega',
#   'residence': '560 Smith Spur\nPort Elizabeth, OH 22254',
#   'sex': 'M',
#   'ssn': '348-45-9747',
#   'username': 'bryanpennington',
#   'website': ['https://www.morgan-medina.com/']},
#  {'address': '7971 Michael Station Suite 025\nMoraleston, MT 56203',
#   'birthdate': datetime.date(2016, 7, 2),
#   'blood_group': 'AB+',
#   'company': 'Thomas Inc',
#   'current_location': (Decimal('77.478359'), Decimal('-17.196430')),
#   'job': 'Early years teacher',
#   'mail': 'vsimpson@gmail.com',
#   'name': 'Cristian Reed',
#   'residence': '89208 Harris Pass\nNorth Wendyhaven, AL 69857',
#   'sex': 'M',
#   'ssn': '213-10-6024',
#   'username': 'ryanward',
#   'website': ['http://thomas.com/',
#    'http://moran-torres.biz/',
#    'https://mays.com/']},
#  {'address': '4454 Roach Parks Apt. 529\nRamseyport, IL 77252',
#   'birthdate': datetime.date(1929, 1, 16),
#   'blood_group': 'B-',
#   'company': 'Mendoza, Simpson and Hunt',
#   'current_location': (Decimal('28.8767845'), Decimal('136.789572')),
#   'job': 'Engineer, chemical',
#   'mail': 'brandoncook@gmail.com',
#   'name': 'Michael Aguilar',
#   'residence': '04033 Tyler Light Suite 476\nJuliamouth, GA 91978',
#   'sex': 'M',
#   'ssn': '006-19-8550',
#   'username': 'smithkevin',
#   'website': ['http://www.green-brown.com/']},
#  {'address': '094 Collins Ways Suite 643\nSarahshire, WV 85103',
#   'birthdate': datetime.date(1972, 9, 13),
#   'blood_group': 'AB-',
#   'company': 'Williams Group',
#   'current_location': (Decimal('-87.7705985'), Decimal('13.492837')),
#   'job': 'Arts administrator',
#   'mail': 'melissa12@gmail.com',
#   'name': 'Steven Rodriguez',
#   'residence': '05126 Natalie Parks Suite 820\nNorth Zacharyhaven, RI 73183',
#   'sex': 'M',
#   'ssn': '049-94-1176',
#   'username': 'afuller',
#   'website': ['https://olsen.com/']},
#  {'address': '17393 Perry Courts Suite 045\nLoriville, MI 57096',
#   'birthdate': datetime.date(1921, 10, 23),
#   'blood_group': 'AB+',
#   'company': 'Lynch and Sons',
#   'current_location': (Decimal('-59.5864775'), Decimal('109.551038')),
#   'job': 'Airline pilot',
#   'mail': 'jbeck@yahoo.com',
#   'name': 'Tim Morgan',
#   'residence': '49853 Cooper Brooks Suite 643\nNorth Jillfort, NH 09959',
#   'sex': 'M',
#   'ssn': '645-02-2076',
#   'username': 'patriciawalker',
#   'website': ['https://chavez.org/',
#    'http://www.serrano.net/',
#    'http://www.love-allen.com/']},
#  {'address': '65517 Alexander Cape\nLake Kristenmouth, AL 06935',
#   'birthdate': datetime.date(1965, 3, 22),
#   'blood_group': 'AB+',
#   'company': 'Greer, Miller and Peck',
#   'current_location': (Decimal('-57.770401'), Decimal('90.278337')),
#   'job': 'Librarian, public',
#   'mail': 'dhansen@gmail.com',
#   'name': 'Robert Pierce',
#   'residence': '3949 Laura Radial\nFoxmouth, NE 52925',
#   'sex': 'M',
#   'ssn': '470-15-3488',
#   'username': 'ruthayala',
#   'website': ['https://www.stewart.com/',
#    'http://miller.com/',
#    'http://mcbride.com/']},
#  {'address': '3443 Moore Way Apt. 263\nEast Jennifershire, IA 82957',
#   'birthdate': datetime.date(2018, 5, 31),
#   'blood_group': 'A+',
#   'company': 'Hernandez, Mcclain and Jones',
#   'current_location': (Decimal('33.5897745'), Decimal('156.639518')),
#   'job': 'Trade mark attorney',
#   'mail': 'katie12@gmail.com',
#   'name': 'Julie Guerra',
#   'residence': '1172 Stephanie Mount\nDylanland, MI 44059',
#   'sex': 'F',
#   'ssn': '358-54-0525',
#   'username': 'fuentestaylor',
#   'website': ['http://www.lewis.com/',
#    'http://moody-manning.biz/',
#    'http://rodriguez-wood.info/',
#    'https://www.norman.com/']},
#  {'address': '540 Rebekah Pine Suite 429\nLake Brianbury, NH 47219',
#   'birthdate': datetime.date(2008, 4, 1),
#   'blood_group': 'A-',
#   'company': 'Miller, Gray and King',
#   'current_location': (Decimal('-15.240301'), Decimal('-155.600229')),
#   'job': 'Corporate investment banker',
#   'mail': 'ncrosby@hotmail.com',
#   'name': 'Sarah Braun',
#   'residence': '20489 Cunningham Valley Suite 105\nPort Andrewton, AL 63781',
#   'sex': 'F',
#   'ssn': '686-19-2981',
#   'username': 'renee58',
#   'website': ['http://gallegos.com/',
#    'http://robinson.com/',
#    'https://www.fuller.com/',
#    'http://bullock-melendez.info/']},
#  {'address': '0160 Roman Valleys\nAnthonyfurt, LA 87846',
#   'birthdate': datetime.date(1955, 9, 28),
#   'blood_group': 'AB+',
#   'company': 'Anderson-Edwards',
#   'current_location': (Decimal('38.9255145'), Decimal('-101.340608')),
#   'job': 'Theatre manager',
#   'mail': 'alisongrant@yahoo.com',
#   'name': 'Patrick Jones',
#   'residence': '33157 Perry Shore Suite 250\nJohnsontown, IN 39634',
#   'sex': 'M',
#   'ssn': '265-25-8042',
#   'username': 'bradleymatthew',
#   'website': ['http://www.schultz.com/',
#    'https://nelson.com/',
#    'https://www.scott.com/']},
#  {'address': '1232 Graham Crescent\nBaxtershire, MO 33316',
#   'birthdate': datetime.date(1995, 3, 30),
#   'blood_group': 'AB-',
#   'company': 'Hernandez-Barron',
#   'current_location': (Decimal('89.248521'), Decimal('-158.920295')),
#   'job': 'Engineer, automotive',
#   'mail': 'whowell@hotmail.com',
#   'name': 'Scott Duncan',
#   'residence': 'USNS Wilkins\nFPO AA 12476',
#   'sex': 'M',
#   'ssn': '884-27-6443',
#   'username': 'xatkinson',
#   'website': ['https://www.rodriguez-mcbride.com/',
#    'https://roth.com/',
#    'http://martinez-bruce.com/']},
#  {'address': '5510 White Terrace Apt. 488\nEast Jeremy, MT 56476',
#   'birthdate': datetime.date(1919, 10, 22),
#   'blood_group': 'B-',
#   'company': 'Kemp-Berry',
#   'current_location': (Decimal('60.970594'), Decimal('146.522590')),
#   'job': 'Development worker, international aid',
#   'mail': 'itate@yahoo.com',
#   'name': 'Tammy Wilson',
#   'residence': '47038 Morris Prairie\nWest Christine, OK 94378',
#   'sex': 'F',
#   'ssn': '581-59-9608',
#   'username': 'williamandersen',
#   'website': ['http://www.booker.com/', 'https://brown.com/']},
#  {'address': '2294 Linda Station\nEast Chad, NY 42746',
#   'birthdate': datetime.date(1984, 4, 8),
#   'blood_group': 'B+',
#   'company': 'Carter, Miller and Rodriguez',
#   'current_location': (Decimal('-70.3699405'), Decimal('-162.467279')),
#   'job': 'Pathologist',
#   'mail': 'derrick48@hotmail.com',
#   'name': 'Tina Coleman',
#   'residence': '869 Russell Pike\nHamiltontown, CO 47815',
#   'sex': 'F',
#   'ssn': '286-03-0110',
#   'username': 'ycooper',
#   'website': ['http://www.gonzalez.com/']},
#  {'address': 'USCGC Scott\nFPO AA 19516',
#   'birthdate': datetime.date(2019, 5, 25),
#   'blood_group': 'O-',
#   'company': 'Wolfe, Hanson and Sweeney',
#   'current_location': (Decimal('-63.2984385'), Decimal('-92.083915')),
#   'job': 'Pilot, airline',
#   'mail': 'stephen13@yahoo.com',
#   'name': 'Melissa Elliott',
#   'residence': '645 Pamela Park Suite 215\nDouglasfort, CA 64731',
#   'sex': 'F',
#   'ssn': '749-48-0333',
#   'username': 'mitchellbrenda',
#   'website': ['https://shaw.net/', 'https://www.powell.com/']},
#  {'address': '4028 James Passage\nSouth Jessicaton, WI 41398',
#   'birthdate': datetime.date(1959, 7, 9),
#   'blood_group': 'A+',
#   'company': 'Robinson, Phelps and Olson',
#   'current_location': (Decimal('-88.557953'), Decimal('165.397443')),
#   'job': 'Industrial/product designer',
#   'mail': 'cohenlee@gmail.com',
#   'name': 'Patrick Patterson',
#   'residence': '913 Nicholas Tunnel\nMckenzieborough, KY 92771',
#   'sex': 'M',
#   'ssn': '090-63-1984',
#   'username': 'juareznicholas',
#   'website': ['http://www.griffin.net/',
#    'https://www.bailey.biz/',
#    'http://williams.net/',
#    'https://www.patrick.info/']},
#  {'address': '88252 Jenna Drive Apt. 813\nSouth Amanda, ND 35000',
#   'birthdate': datetime.date(1907, 11, 24),
#   'blood_group': 'O-',
#   'company': 'Perry Inc',
#   'current_location': (Decimal('78.414117'), Decimal('14.197025')),
#   'job': 'Psychologist, occupational',
#   'mail': 'umcneil@hotmail.com',
#   'name': 'Elizabeth Sanchez',
#   'residence': '220 Sanchez Radial\nNew Karen, ID 69580',
#   'sex': 'F',
#   'ssn': '407-98-4990',
#   'username': 'jennaruiz',
#   'website': ['https://glover-thomas.org/']},
#  {'address': '59432 Keith Manor Suite 389\nPort Samuelfurt, CT 11274',
#   'birthdate': datetime.date(1977, 12, 1),
#   'blood_group': 'O+',
#   'company': 'Chang, Webb and Sanchez',
#   'current_location': (Decimal('68.836841'), Decimal('-94.756544')),
#   'job': 'Corporate treasurer',
#   'mail': 'frank50@hotmail.com',
#   'name': 'Linda Payne',
#   'residence': '58613 Graves Route\nArchershire, NM 86830',
#   'sex': 'F',
#   'ssn': '381-86-5994',
#   'username': 'mary92',
#   'website': ['http://lang.com/',
#    'https://www.elliott.com/',
#    'http://greene-parrish.com/']},
#  {'address': '953 Beltran Trace Suite 599\nLake Dalemouth, SC 47107',
#   'birthdate': datetime.date(1980, 2, 10),
#   'blood_group': 'AB-',
#   'company': 'Butler Inc',
#   'current_location': (Decimal('40.901564'), Decimal('-54.438789')),
#   'job': 'Administrator, charities/voluntary organisations',
#   'mail': 'williamsthomas@gmail.com',
#   'name': 'Cody Guerra',
#   'residence': '29929 Tamara Pass Suite 935\nNorth Derrick, ID 45173',
#   'sex': 'M',
#   'ssn': '409-50-3363',
#   'username': 'donaldwilliams',
#   'website': ['https://aguilar.info/', 'https://durham-hudson.com/']},
#  {'address': '854 Amanda Pike\nCrystalstad, PA 67918',
#   'birthdate': datetime.date(1972, 6, 29),
#   'blood_group': 'A-',
#   'company': 'Moore LLC',
#   'current_location': (Decimal('-86.669025'), Decimal('58.500060')),
#   'job': 'Medical laboratory scientific officer',
#   'mail': 'jeffersongregory@hotmail.com',
#   'name': 'Cynthia Nelson',
#   'residence': '99903 Zachary Locks Apt. 894\nWilliamsburgh, NY 66201',
#   'sex': 'F',
#   'ssn': '440-61-8213',
#   'username': 'lynchglenn',
#   'website': ['http://www.berry.com/']},
#  {'address': '2227 Smith Common Apt. 491\nGarciastad, MO 58196',
#   'birthdate': datetime.date(1933, 6, 8),
#   'blood_group': 'AB-',
#   'company': 'Ruiz Ltd',
#   'current_location': (Decimal('-77.0740425'), Decimal('-162.610312')),
#   'job': 'Land',
#   'mail': 'dgutierrez@hotmail.com',
#   'name': 'Danielle Perkins',
#   'residence': '00589 Wallace Shoals Apt. 404\nEast Michaelton, AR 72730',
#   'sex': 'F',
#   'ssn': '597-63-8071',
#   'username': 'williamkramer',
#   'website': ['http://johnson.com/']},
#  {'address': '62717 Baldwin Square\nHayesmouth, VA 15998',
#   'birthdate': datetime.date(1921, 7, 10),
#   'blood_group': 'AB+',
#   'company': 'Acosta, Daniels and Adams',
#   'current_location': (Decimal('-23.0632645'), Decimal('-86.596442')),
#   'job': 'Control and instrumentation engineer',
#   'mail': 'roger00@yahoo.com',
#   'name': 'Jennifer Jones',
#   'residence': '09853 Wallace Skyway Suite 442\nSouth Cassandra, NC 02443',
#   'sex': 'F',
#   'ssn': '365-64-8388',
#   'username': 'natalie75',
#   'website': ['https://howard-lyons.org/',
#    'https://www.lowe.net/',
#    'http://johnson.biz/',
#    'http://patel.com/']},
#  {'address': '3256 Thomas Mountain\nFlemington, UT 06711',
#   'birthdate': datetime.date(1953, 4, 9),
#   'blood_group': 'O+',
#   'company': 'Schultz, Goodman and Smith',
#   'current_location': (Decimal('75.766937'), Decimal('33.269978')),
#   'job': 'Psychologist, forensic',
#   'mail': 'rebeccareid@yahoo.com',
#   'name': 'Deborah Cantrell',
#   'residence': '37764 James Junction Apt. 336\nJustinborough, ND 63932',
#   'sex': 'F',
#   'ssn': '259-15-8208',
#   'username': 'pameladavis',
#   'website': ['https://www.shepherd.com/',
#    'https://www.jones-brown.com/',
#    'https://www.hudson.com/']},
#  {'address': '8879 Spencer Park Suite 440\nSouth Mason, IL 48311',
#   'birthdate': datetime.date(1917, 2, 17),
#   'blood_group': 'A+',
#   'company': 'Parker, Rodriguez and Barnett',
#   'current_location': (Decimal('-44.4248235'), Decimal('-114.030449')),
#   'job': 'Lighting technician, broadcasting/film/video',
#   'mail': 'curtis02@hotmail.com',
#   'name': 'Jerry Garcia',
#   'residence': '1467 Ware Causeway\nEast Travis, NY 63215',
#   'sex': 'M',
#   'ssn': '615-03-1373',
#   'username': 'clarkmichael',
#   'website': ['http://www.peters.com/',
#    'https://richards-sherman.biz/',
#    'http://www.moore.net/']},
#  {'address': '3115 Amy Wall Suite 307\nWest Adam, MT 17568',
#   'birthdate': datetime.date(1917, 7, 15),
#   'blood_group': 'O+',
#   'company': 'Mcclure-Jackson',
#   'current_location': (Decimal('-48.444630'), Decimal('-174.535910')),
#   'job': 'Museum/gallery exhibitions officer',
#   'mail': 'evelyn64@yahoo.com',
#   'name': 'Elizabeth Moon',
#   'residence': '7002 Stacie Shoal\nPort Joelland, FL 28137',
#   'sex': 'F',
#   'ssn': '309-81-9715',
#   'username': 'jane22',
#   'website': ['http://rush.biz/', 'http://www.roman-erickson.org/']},
#  {'address': '53306 Monique Avenue\nWendyfort, RI 39871',
#   'birthdate': datetime.date(1945, 8, 5),
#   'blood_group': 'AB+',
#   'company': 'Jones, Washington and Petty',
#   'current_location': (Decimal('30.7966335'), Decimal('-6.581498')),
#   'job': 'Travel agency manager',
#   'mail': 'ortizkim@yahoo.com',
#   'name': 'Emily Wolfe',
#   'residence': '248 Butler Field Suite 428\nWest Alexa, NE 63791',
#   'sex': 'F',
#   'ssn': '793-31-0578',
#   'username': 'jrobinson',
#   'website': ['https://www.gonzalez.biz/',
#    'https://www.james.org/',
#    'http://www.gomez.com/',
#    'https://www.williams-martinez.com/']},
#  {'address': '72616 Alexandra Park\nRitterland, RI 68234',
#   'birthdate': datetime.date(1914, 11, 30),
#   'blood_group': 'B+',
#   'company': 'Zimmerman-Gomez',
#   'current_location': (Decimal('-81.8425115'), Decimal('-175.450921')),
#   'job': 'Banker',
#   'mail': 'alane@yahoo.com',
#   'name': 'Heather Burgess',
#   'residence': '44368 Schwartz Gardens\nWest Jennifer, LA 94102',
#   'sex': 'F',
#   'ssn': '682-34-1074',
#   'username': 'autumnsmith',
#   'website': ['http://www.nicholson-ramsey.com/',
#    'https://perry-zhang.org/',
#    'https://andrade.info/']},
#  {'address': '205 David Harbors\nKylefurt, AK 28148',
#   'birthdate': datetime.date(1965, 9, 11),
#   'blood_group': 'AB-',
#   'company': 'Ramirez PLC',
#   'current_location': (Decimal('25.1730805'), Decimal('10.846985')),
#   'job': 'Intelligence analyst',
#   'mail': 'xclay@gmail.com',
#   'name': 'Daniel Gonzales',
#   'residence': '64826 Ashley Ridges\nRobbinsside, NV 48202',
#   'sex': 'M',
#   'ssn': '354-96-6840',
#   'username': 'morganmelissa',
#   'website': ['http://www.brown.com/', 'https://smith.net/']},
#  {'address': '9016 Fowler Mountain\nEast Shelly, IL 72088',
#   'birthdate': datetime.date(1985, 8, 19),
#   'blood_group': 'A-',
#   'company': 'Garcia Inc',
#   'current_location': (Decimal('9.772636'), Decimal('-12.001993')),
#   'job': 'Equality and diversity officer',
#   'mail': 'laurieandrews@yahoo.com',
#   'name': 'Shaun Hanson',
#   'residence': '090 Tonya Estate\nSmithside, FL 15044',
#   'sex': 'M',
#   'ssn': '838-55-6082',
#   'username': 'victorrobertson',
#   'website': ['http://www.jackson.com/',
#    'https://www.young-watson.com/',
#    'http://www.brown.biz/']},
#  {'address': '6090 Richmond Summit\nDanielsburgh, ID 81260',
#   'birthdate': datetime.date(1936, 5, 23),
#   'blood_group': 'A+',
#   'company': 'Nelson, Gonzalez and Martin',
#   'current_location': (Decimal('88.021553'), Decimal('139.013619')),
#   'job': 'Primary school teacher',
#   'mail': 'laurie36@yahoo.com',
#   'name': 'Nicholas Brown',
#   'residence': 'PSC 2975, Box 8453\nAPO AP 08217',
#   'sex': 'M',
#   'ssn': '176-69-7478',
#   'username': 'rlee',
#   'website': ['http://erickson.com/',
#    'http://www.ayers.com/',
#    'http://www.goodwin.com/',
#    'http://www.smith.com/']},
#  {'address': '14194 Amanda Centers\nJohnsonhaven, OH 60356',
#   'birthdate': datetime.date(1977, 10, 19),
#   'blood_group': 'A+',
#   'company': 'Harris, Hubbard and Johnson',
#   'current_location': (Decimal('-77.307596'), Decimal('-68.565091')),
#   'job': 'Development worker, international aid',
#   'mail': 'bradyjessica@yahoo.com',
#   'name': 'Charles Brooks',
#   'residence': '852 Gabriella Rue Suite 726\nKatherineshire, NJ 19437',
#   'sex': 'M',
#   'ssn': '417-77-7467',
#   'username': 'jonathannichols',
#   'website': ['https://green-moore.net/',
#    'https://walker.com/',
#    'http://stevenson.info/']},
#  {'address': '4813 Andrews Via\nPotterborough, SC 55171',
#   'birthdate': datetime.date(1928, 3, 12),
#   'blood_group': 'AB-',
#   'company': 'White, Wilson and Scott',
#   'current_location': (Decimal('2.200841'), Decimal('5.514815')),
#   'job': 'Associate Professor',
#   'mail': 'hannahdouglas@yahoo.com',
#   'name': 'Kim Knight',
#   'residence': '7178 Samantha Corner Apt. 146\nNorth Bryan, CA 45850',
#   'sex': 'F',
#   'ssn': '778-36-9848',
#   'username': 'garciasteven',
#   'website': ['http://smith.net/',
#    'https://rodgers-howell.com/',
#    'https://king-booker.info/']},
#  {'address': '9083 Curtis Gardens\nNorth Josephmouth, MI 43623',
#   'birthdate': datetime.date(1967, 1, 10),
#   'blood_group': 'AB+',
#   'company': 'Marsh LLC',
#   'current_location': (Decimal('-58.114270'), Decimal('-109.938944')),
#   'job': 'Engineer, control and instrumentation',
#   'mail': 'christina47@hotmail.com',
#   'name': 'Cindy Martin',
#   'residence': '646 Anderson Oval Suite 005\nNew Deniseshire, ME 08472',
#   'sex': 'F',
#   'ssn': '328-32-1818',
#   'username': 'johnchristian',
#   'website': ['http://www.santos.info/',
#    'http://www.good.biz/',
#    'https://singh.com/']},
#  {'address': '800 Shannon Harbor\nEast Christyfurt, KY 32749',
#   'birthdate': datetime.date(1919, 3, 6),
#   'blood_group': 'B-',
#   'company': 'Stewart LLC',
#   'current_location': (Decimal('-52.9561975'), Decimal('132.959527')),
#   'job': 'Estate agent',
#   'mail': 'edward15@yahoo.com',
#   'name': 'Mario Phillips',
#   'residence': '8385 Ortiz Forks Apt. 001\nNew Melissamouth, SC 92051',
#   'sex': 'M',
#   'ssn': '479-14-4526',
#   'username': 'kristinapatterson',
#   'website': ['https://www.ford-russell.com/',
#    'http://allen-gray.info/',
#    'http://www.white.com/',
#    'https://www.taylor-davis.net/']},
#  {'address': 'USNV Espinoza\nFPO AP 71793',
#   'birthdate': datetime.date(1913, 10, 16),
#   'blood_group': 'AB-',
#   'company': 'Torres PLC',
#   'current_location': (Decimal('-15.059445'), Decimal('-94.615530')),
#   'job': 'Psychologist, sport and exercise',
#   'mail': 'emily17@hotmail.com',
#   'name': 'Erika Orozco',
#   'residence': '402 Mary Glen Apt. 051\nWilliambury, ME 49422',
#   'sex': 'F',
#   'ssn': '876-07-6278',
#   'username': 'piercenicholas',
#   'website': ['https://www.gonzales-ortiz.com/',
#    'http://www.graham.com/',
#    'http://www.lucas-phillips.com/',
#    'http://www.hughes.info/']},
#  {'address': '39462 Christine Trace Apt. 698\nEast James, UT 48122',
#   'birthdate': datetime.date(1934, 8, 5),
#   'blood_group': 'AB-',
#   'company': 'Mosley, Martinez and Mcfarland',
#   'current_location': (Decimal('37.9802105'), Decimal('146.572643')),
#   'job': 'Health promotion specialist',
#   'mail': 'brandyperez@hotmail.com',
#   'name': 'Patricia Reed',
#   'residence': '91859 Payne Isle Apt. 451\nLake Cheryl, LA 75247',
#   'sex': 'F',
#   'ssn': '170-94-2785',
#   'username': 'jon67',
#   'website': ['https://www.martinez-smith.com/']},
#  {'address': '7808 David Ways\nNorth Veronicaberg, MT 39785',
#   'birthdate': datetime.date(1971, 5, 14),
#   'blood_group': 'B+',
#   'company': 'Brown-Parker',
#   'current_location': (Decimal('49.741524'), Decimal('-114.307423')),
#   'job': 'Structural engineer',
#   'mail': 'amanda46@gmail.com',
#   'name': 'Lori Benitez',
#   'residence': '767 Kayla Fields\nWest Rebecca, RI 78869',
#   'sex': 'F',
#   'ssn': '103-40-4975',
#   'username': 'foxvictoria',
#   'website': ['http://thompson.com/',
#    'https://bell.org/',
#    'https://powell-maynard.com/']},
#  {'address': '94205 Clark Land Apt. 116\nLake Jacobstad, ID 89499',
#   'birthdate': datetime.date(1967, 12, 20),
#   'blood_group': 'O-',
#   'company': 'Snyder-Jones',
#   'current_location': (Decimal('18.704225'), Decimal('126.050162')),
#   'job': 'Haematologist',
#   'mail': 'bradleycuevas@hotmail.com',
#   'name': 'Michele Riley',
#   'residence': '8961 Laurie Walk Suite 871\nPort Andreaburgh, KS 56313',
#   'sex': 'F',
#   'ssn': '445-58-3630',
#   'username': 'robert25',
#   'website': ['http://humphrey.com/']},
#  {'address': '6648 Carla Oval Apt. 402\nEast Christopher, WY 68388',
#   'birthdate': datetime.date(1913, 3, 22),
#   'blood_group': 'O+',
#   'company': 'Boyd-Lewis',
#   'current_location': (Decimal('37.957447'), Decimal('-7.864700')),
#   'job': 'Museum/gallery exhibitions officer',
#   'mail': 'afoster@yahoo.com',
#   'name': 'Amy Bowman',
#   'residence': '7858 Robert Isle Apt. 361\nHunterview, VT 47315',
#   'sex': 'F',
#   'ssn': '594-80-6194',
#   'username': 'cynthia42',
#   'website': ['https://wright.net/', 'http://www.mcgrath.com/']},
#  {'address': '482 Eric Motorway Suite 091\nLake Christinechester, OR 48181',
#   'birthdate': datetime.date(1937, 8, 19),
#   'blood_group': 'O-',
#   'company': 'Berry-Nguyen',
#   'current_location': (Decimal('-48.4955695'), Decimal('-72.784462')),
#   'job': 'Librarian, public',
#   'mail': 'chall@gmail.com',
#   'name': 'Charles Richmond',
#   'residence': '67621 Roberto Circles Suite 555\nWest Robertburgh, LA 29430',
#   'sex': 'M',
#   'ssn': '286-19-1803',
#   'username': 'danielsdanielle',
#   'website': ['https://www.jackson.net/',
#    'https://brown-king.com/',
#    'https://www.scott.com/']},
#  {'address': '5777 Benitez Shores\nPort Cory, NJ 32511',
#   'birthdate': datetime.date(1985, 11, 23),
#   'blood_group': 'O-',
#   'company': 'Chavez-Conner',
#   'current_location': (Decimal('74.9630265'), Decimal('-120.421886')),
#   'job': 'Surveyor, building control',
#   'mail': 'robinjohnson@hotmail.com',
#   'name': 'Samantha Hernandez',
#   'residence': '40414 Joyce Dam Apt. 090\nCarlaville, CA 77800',
#   'sex': 'F',
#   'ssn': '562-24-4460',
#   'username': 'terrigreene',
#   'website': ['https://www.page.com/', 'https://www.adkins-campbell.com/']},
#  {'address': '14243 Randy Estates\nSouth Kristineborough, OR 67302',
#   'birthdate': datetime.date(1927, 4, 5),
#   'blood_group': 'AB+',
#   'company': 'Nelson PLC',
#   'current_location': (Decimal('44.3636535'), Decimal('8.188656')),
#   'job': 'Social research officer, government',
#   'mail': 'cathyhicks@hotmail.com',
#   'name': 'Bryan Hudson',
#   'residence': '84711 Stanton Greens Apt. 600\nLake Jennifer, NC 92705',
#   'sex': 'M',
#   'ssn': '004-01-7189',
#   'username': 'braunkenneth',
#   'website': ['http://hughes.com/',
#    'http://www.swanson.biz/',
#    'https://crawford.com/',
#    'http://www.cisneros.com/']},
#  {'address': '76559 Donna Mission\nWest Donaldchester, ND 61773',
#   'birthdate': datetime.date(1954, 4, 23),
#   'blood_group': 'AB-',
#   'company': 'Miller Inc',
#   'current_location': (Decimal('-48.2268245'), Decimal('44.965230')),
#   'job': 'Scientist, forensic',
#   'mail': 'christopher58@gmail.com',
#   'name': 'Albert Peters',
#   'residence': '07002 Pamela Falls Apt. 104\nPort Erinshire, WI 52077',
#   'sex': 'M',
#   'ssn': '568-15-8516',
#   'username': 'ccarrillo',
#   'website': ['https://www.harvey.com/']},
#  {'address': '4565 Clark Landing\nWest Jessicaton, SD 01112',
#   'birthdate': datetime.date(1936, 10, 10),
#   'blood_group': 'B+',
#   'company': 'Marshall Inc',
#   'current_location': (Decimal('73.4007675'), Decimal('72.669070')),
#   'job': 'Furniture designer',
#   'mail': 'ronald47@gmail.com',
#   'name': 'Gabriela Ward',
#   'residence': '6131 Marc Lakes\nMichaelport, NY 35636',
#   'sex': 'F',
#   'ssn': '325-92-2742',
#   'username': 'joseph83',
#   'website': ['http://www.hernandez-patterson.info/',
#    'http://vaughan-evans.com/']},
#  {'address': 'PSC 5013, Box 3824\nAPO AA 20684',
#   'birthdate': datetime.date(1965, 5, 15),
#   'blood_group': 'AB+',
#   'company': 'Thompson-Walsh',
#   'current_location': (Decimal('-86.666444'), Decimal('-45.064060')),
#   'job': 'Geologist, engineering',
#   'mail': 'bbrock@gmail.com',
#   'name': 'Elizabeth Estes',
#   'residence': '255 Clinton Shores\nBurkestad, WV 62981',
#   'sex': 'F',
#   'ssn': '511-17-3103',
#   'username': 'erikcraig',
#   'website': ['https://hernandez.com/', 'http://www.simmons.com/']},
#  {'address': '987 Johnson Mall\nEast Mitchell, KY 03618',
#   'birthdate': datetime.date(2000, 2, 24),
#   'blood_group': 'B+',
#   'company': 'Pena, Hernandez and Parker',
#   'current_location': (Decimal('16.4840015'), Decimal('83.600954')),
#   'job': 'Pensions consultant',
#   'mail': 'lynnroth@gmail.com',
#   'name': 'Rhonda Hodge',
#   'residence': '3473 Shelley Rest\nWeberchester, CA 91727',
#   'sex': 'F',
#   'ssn': '639-99-7635',
#   'username': 'brianhanson',
#   'website': ['https://molina.info/', 'http://www.jones.org/']},
#  {'address': '380 Ashley Coves Apt. 773\nPort Sabrinaton, WV 82827',
#   'birthdate': datetime.date(1945, 3, 27),
#   'blood_group': 'A+',
#   'company': 'Cummings PLC',
#   'current_location': (Decimal('-12.363766'), Decimal('45.755570')),
#   'job': 'Clothing/textile technologist',
#   'mail': 'roseherrera@gmail.com',
#   'name': 'Jennifer Beasley',
#   'residence': '69958 Monique Underpass\nAguilarville, NV 93085',
#   'sex': 'F',
#   'ssn': '184-96-0114',
#   'username': 'april03',
#   'website': ['https://www.little.com/',
#    'https://www.barnes.com/',
#    'http://tran.com/',
#    'http://ramsey.com/']},
#  {'address': '75542 Henry Burgs Suite 663\nWest Katie, CO 33259',
#   'birthdate': datetime.date(1949, 10, 16),
#   'blood_group': 'O+',
#   'company': 'Taylor-Rivera',
#   'current_location': (Decimal('-76.8526485'), Decimal('-54.559747')),
#   'job': 'Nurse, mental health',
#   'mail': 'jasonodom@yahoo.com',
#   'name': 'Michelle Roberts',
#   'residence': 'PSC 2412, Box 4425\nAPO AE 46565',
#   'sex': 'F',
#   'ssn': '631-29-7350',
#   'username': 'arnoldkristin',
#   'website': ['https://bell.com/', 'https://www.sanders-jones.net/']},
#  {'address': '04244 Carol Falls\nNorth Lori, MS 79800',
#   'birthdate': datetime.date(2003, 3, 11),
#   'blood_group': 'O+',
#   'company': 'Fernandez, Baird and Turner',
#   'current_location': (Decimal('79.435099'), Decimal('40.115103')),
#   'job': 'Ceramics designer',
#   'mail': 'stanleymadison@yahoo.com',
#   'name': 'Lisa Johnson',
#   'residence': '814 Tyler Parks Apt. 196\nWest Alejandrahaven, RI 65475',
#   'sex': 'F',
#   'ssn': '497-33-5455',
#   'username': 'stephensdennis',
#   'website': ['http://www.bennett.info/',
#    'http://hanson-hall.com/',
#    'https://www.davenport-sanders.com/']},
#  {'address': '331 Ramirez Hollow\nSheilaburgh, WY 27044',
#   'birthdate': datetime.date(1992, 5, 29),
#   'blood_group': 'A+',
#   'company': 'Jones, Ruiz and Lopez',
#   'current_location': (Decimal('44.381624'), Decimal('-165.432816')),
#   'job': 'Control and instrumentation engineer',
#   'mail': 'hopkinscarolyn@gmail.com',
#   'name': 'William Sullivan',
#   'residence': '5102 Waller Vista Apt. 248\nEast Douglas, CA 10744',
#   'sex': 'M',
#   'ssn': '857-57-9047',
#   'username': 'castillotonya',
#   'website': ['http://www.thompson.org/',
#    'http://meyer.com/',
#    'http://watson.com/']},
#  {'address': '67504 Carl Shores Apt. 755\nWest Michelle, NM 61591',
#   'birthdate': datetime.date(1984, 6, 3),
#   'blood_group': 'B-',
#   'company': 'Douglas, Jackson and Jones',
#   'current_location': (Decimal('-41.239320'), Decimal('159.901075')),
#   'job': 'Designer, graphic',
#   'mail': 'jerrywelch@hotmail.com',
#   'name': 'Robin Munoz',
#   'residence': 'USS Kim\nFPO AE 02478',
#   'sex': 'F',
#   'ssn': '190-12-6465',
#   'username': 'rodriguezmatthew',
#   'website': ['http://little-mcclain.com/',
#    'https://everett-maxwell.org/',
#    'http://best-adkins.com/',
#    'http://johnson.com/']},
#  {'address': '8009 David Roads Apt. 150\nCatherinebury, RI 65328',
#   'birthdate': datetime.date(1936, 11, 20),
#   'blood_group': 'AB-',
#   'company': 'Walker Inc',
#   'current_location': (Decimal('17.1756305'), Decimal('179.572002')),
#   'job': 'Public relations officer',
#   'mail': 'amandanguyen@hotmail.com',
#   'name': 'Stephanie Williams',
#   'residence': '36777 Carl Lock\nMichaelland, MI 27009',
#   'sex': 'F',
#   'ssn': '394-47-6467',
#   'username': 'sarajones',
#   'website': ['https://dawson.com/',
#    'https://www.davidson-daniel.com/',
#    'https://mcclain-rubio.net/',
#    'http://salazar-smith.org/']},
#  {'address': '7896 Gail Lake Suite 536\nMurraystad, SD 20032',
#   'birthdate': datetime.date(1961, 4, 2),
#   'blood_group': 'AB-',
#   'company': 'Duarte, Blair and Munoz',
#   'current_location': (Decimal('9.435848'), Decimal('55.920090')),
#   'job': 'Animal technologist',
#   'mail': 'ylara@hotmail.com',
#   'name': 'Courtney Jordan MD',
#   'residence': 'PSC 1806, Box 8061\nAPO AA 13432',
#   'sex': 'F',
#   'ssn': '667-82-3557',
#   'username': 'hudsonpatrick',
#   'website': ['https://jones-page.com/']},
#  {'address': '94892 Allen Avenue Suite 462\nNew Jamieside, MO 32972',
#   'birthdate': datetime.date(1933, 12, 25),
#   'blood_group': 'O+',
#   'company': 'Parsons, Torres and Hunter',
#   'current_location': (Decimal('89.0240935'), Decimal('119.986469')),
#   'job': 'Prison officer',
#   'mail': 'oscar64@yahoo.com',
#   'name': 'Steven Smith',
#   'residence': '531 Willie Shore\nNorth Jillian, WY 01543',
#   'sex': 'M',
#   'ssn': '706-95-2609',
#   'username': 'pamela25',
#   'website': ['http://www.gutierrez-rivas.net/', 'http://www.lyons.com/']},
#  {'address': '30628 Donald Turnpike Apt. 886\nEast Deborahborough, UT 69146',
#   'birthdate': datetime.date(1946, 7, 15),
#   'blood_group': 'AB-',
#   'company': 'Nicholson, Taylor and Hernandez',
#   'current_location': (Decimal('48.547086'), Decimal('81.643384')),
#   'job': 'Social worker',
#   'mail': 'melindajackson@gmail.com',
#   'name': 'Brenda Mason',
#   'residence': '6708 Jonathan Landing\nLake Regina, SD 17589',
#   'sex': 'F',
#   'ssn': '213-31-3314',
#   'username': 'stevensjimmy',
#   'website': ['https://bennett-figueroa.com/', 'http://scott-ward.biz/']},
#  {'address': '9271 Mclean Motorway Suite 991\nSouth Michaelchester, WV 21134',
#   'birthdate': datetime.date(1922, 4, 13),
#   'blood_group': 'A+',
#   'company': 'Lambert, Chan and Scott',
#   'current_location': (Decimal('49.5539855'), Decimal('134.118897')),
#   'job': 'Rural practice surveyor',
#   'mail': 'thomaswarren@gmail.com',
#   'name': 'Daniel Matthews',
#   'residence': '95963 Mccoy Well\nGarciaberg, ND 37956',
#   'sex': 'M',
#   'ssn': '771-35-7902',
#   'username': 'frank36',
#   'website': ['http://www.conner.com/',
#    'http://ramirez.org/',
#    'https://www.smith.info/',
#    'https://simpson.com/']},
#  {'address': '12068 Sandra Stream\nSusantown, VA 81229',
#   'birthdate': datetime.date(1936, 9, 1),
#   'blood_group': 'AB-',
#   'company': 'Walker, Charles and Zamora',
#   'current_location': (Decimal('0.2843975'), Decimal('-122.218044')),
#   'job': 'Careers adviser',
#   'mail': 'russellamber@gmail.com',
#   'name': 'Jesse Burns',
#   'residence': '12129 Carrie Crossing Apt. 114\nWest Christopher, WI 76053',
#   'sex': 'M',
#   'ssn': '359-38-7794',
#   'username': 'travisrodriguez',
#   'website': ['https://www.swanson.info/',
#    'http://mccoy.com/',
#    'http://www.riddle-swanson.com/',
#    'https://preston.com/']},
#  {'address': '95383 Frances Fort Suite 248\nLaurenmouth, ME 49177',
#   'birthdate': datetime.date(1982, 3, 30),
#   'blood_group': 'AB+',
#   'company': 'Villegas-Smith',
#   'current_location': (Decimal('-45.6402265'), Decimal('-36.345001')),
#   'job': 'Surveyor, rural practice',
#   'mail': 'imay@gmail.com',
#   'name': 'Emily Brady',
#   'residence': '31191 Anderson Pike\nNew Joseph, MO 62986',
#   'sex': 'F',
#   'ssn': '239-22-7850',
#   'username': 'edwardsryan',
#   'website': ['https://esparza-king.com/']},
#  {'address': '0476 Bianca Extensions\nNew Donald, ND 39141',
#   'birthdate': datetime.date(1950, 3, 24),
#   'blood_group': 'AB+',
#   'company': 'Melton-Crawford',
#   'current_location': (Decimal('-41.291446'), Decimal('-40.063086')),
#   'job': 'Communications engineer',
#   'mail': 'lthomas@hotmail.com',
#   'name': 'Taylor Conrad',
#   'residence': 'PSC 5120, Box 0417\nAPO AA 82284',
#   'sex': 'F',
#   'ssn': '424-64-4732',
#   'username': 'jennifer66',
#   'website': ['http://www.morales.org/',
#    'http://www.davenport-sanchez.biz/',
#    'http://jones.net/']},
#  {'address': '0029 Thompson Station Suite 096\nKarenborough, RI 75675',
#   'birthdate': datetime.date(2016, 2, 29),
#   'blood_group': 'O-',
#   'company': 'Nelson-Rich',
#   'current_location': (Decimal('-18.424137'), Decimal('160.304702')),
#   'job': 'Education officer, museum',
#   'mail': 'kellydoyle@hotmail.com',
#   'name': 'David Juarez',
#   'residence': '777 Amber Street\nPort Robert, CO 30246',
#   'sex': 'M',
#   'ssn': '106-63-9742',
#   'username': 'albert32',
#   'website': ['http://garcia.com/',
#    'http://www.taylor.biz/',
#    'http://www.stephens.biz/',
#    'https://www.hahn-moon.com/']},
#  {'address': 'PSC 3416, Box 2399\nAPO AP 54303',
#   'birthdate': datetime.date(1964, 10, 8),
#   'blood_group': 'AB-',
#   'company': 'Berry, Hogan and Edwards',
#   'current_location': (Decimal('-86.974549'), Decimal('-9.980823')),
#   'job': 'Geoscientist',
#   'mail': 'jasonhale@gmail.com',
#   'name': 'Peter Baker',
#   'residence': 'USCGC Lucas\nFPO AE 56102',
#   'sex': 'M',
#   'ssn': '745-57-5308',
#   'username': 'smithcathy',
#   'website': ['https://www.vaughn.com/']},
#  {'address': '82485 Mcintosh Lakes Apt. 971\nKristyview, SC 62303',
#   'birthdate': datetime.date(1985, 9, 20),
#   'blood_group': 'AB-',
#   'company': 'Avila LLC',
#   'current_location': (Decimal('-1.7492265'), Decimal('74.027246')),
#   'job': 'Maintenance engineer',
#   'mail': 'chapmankimberly@hotmail.com',
#   'name': 'Walter Rojas',
#   'residence': '603 Morgan Dam\nEast Brittanymouth, VT 30154',
#   'sex': 'M',
#   'ssn': '594-43-7316',
#   'username': 'catherinesolis',
#   'website': ['http://walker.com/',
#    'https://www.ford-fuller.com/',
#    'https://www.melendez.com/',
#    'http://reid.com/']},
#  {'address': '69699 Melissa Lodge\nJameshaven, HI 24278',
#   'birthdate': datetime.date(1929, 6, 6),
#   'blood_group': 'B+',
#   'company': 'Miller-King',
#   'current_location': (Decimal('-26.358536'), Decimal('175.379505')),
#   'job': 'Mechanical engineer',
#   'mail': 'smithbrittany@yahoo.com',
#   'name': 'Johnathan King',
#   'residence': '5613 Rivera Points Apt. 689\nHinesshire, AL 94623',
#   'sex': 'M',
#   'ssn': '743-35-0638',
#   'username': 'jessica97',
#   'website': ['https://hayes.com/']},
#  {'address': '7910 White Knoll\nThompsonshire, UT 07914',
#   'birthdate': datetime.date(1956, 7, 29),
#   'blood_group': 'A-',
#   'company': 'Hart-Mccarthy',
#   'current_location': (Decimal('43.5954695'), Decimal('-175.826319')),
#   'job': 'Financial trader',
#   'mail': 'bmoore@hotmail.com',
#   'name': 'Brett French',
#   'residence': '464 Martinez Land Apt. 503\nEllisside, OK 10715',
#   'sex': 'M',
#   'ssn': '045-48-6849',
#   'username': 'smithamanda',
# ...
#   'sex': 'F',
#   'ssn': '528-18-1894',
#   'username': 'rangelcarla',
#   'website': ['https://www.anderson.org/']},
#  {'address': '302 Cox Course Apt. 079\nLake Jane, MO 79410',
#   'birthdate': datetime.date(1974, 12, 11),
#   'blood_group': 'O+',
#   'company': 'Wiley, Hayes and Mcdowell',
#   'current_location': (Decimal('55.831411'), Decimal('-31.787602')),
#   'job': 'Acupuncturist',
#   'mail': 'alexis12@yahoo.com',
#   'name': 'Linda Ochoa',
#   'residence': '9424 Colleen Extension\nNew Jacquelinebury, DE 49520',
#   'sex': 'F',
#   'ssn': '367-90-9873',
#   'username': 'maria63',
#   'website': ['https://young.com/',
#    'https://www.wang.com/',
#    'http://www.franklin.com/']},
#  {'address': '402 Russell Squares\nNorth Martinport, KS 81865',
#   'birthdate': datetime.date(1981, 12, 19),
#   'blood_group': 'A+',
#   'company': 'Lowe, Smith and Sanchez',
#   'current_location': (Decimal('33.0966615'), Decimal('-90.522578')),
#   'job': 'Control and instrumentation engineer',
#   'mail': 'emiles@gmail.com',
#   'name': 'Joseph Forbes',
#   'residence': '625 Luke Ville Apt. 814\nWest Daniel, RI 14459',
#   'sex': 'M',
#   'ssn': '888-09-6041',
#   'username': 'espinozajoshua',
#   'website': ['https://www.harvey-king.com/', 'https://burton.com/']},
#  {'address': '6519 Joy Viaduct\nCraigmouth, KY 83022',
#   'birthdate': datetime.date(1987, 7, 25),
#   'blood_group': 'AB-',
#   'company': 'Chen, Johnston and Cooper',
#   'current_location': (Decimal('-81.993345'), Decimal('10.728555')),
#   'job': 'Secretary/administrator',
#   'mail': 'colin71@hotmail.com',
#   'name': 'Mr. Michael Hickman DDS',
#   'residence': '62746 Chung Skyway Apt. 682\nPort Anthony, MO 95178',
#   'sex': 'M',
#   'ssn': '282-49-5904',
#   'username': 'icarr',
#   'website': ['http://smith-le.info/',
#    'http://www.cameron-jacobs.org/',
#    'http://garcia.com/']},
#  {'address': '360 Miller Islands\nJoshuatown, UT 43694',
#   'birthdate': datetime.date(1959, 6, 28),
#   'blood_group': 'B-',
#   'company': 'Oconnell Group',
#   'current_location': (Decimal('85.914381'), Decimal('95.427632')),
#   'job': 'Librarian, academic',
#   'mail': 'nicole14@yahoo.com',
#   'name': 'Melanie Tyler',
#   'residence': '2361 Julia Shoal\nPort Andrew, MN 83794',
#   'sex': 'F',
#   'ssn': '084-89-3419',
#   'username': 'hhunt',
#   'website': ['http://edwards.info/',
#    'http://gray.com/',
#    'https://www.rodriguez.net/']},
#  {'address': 'PSC 9565, Box 8897\nAPO AA 95494',
#   'birthdate': datetime.date(1988, 5, 17),
#   'blood_group': 'O+',
#   'company': 'Montgomery-Wilson',
#   'current_location': (Decimal('-41.328338'), Decimal('33.424946')),
#   'job': 'Therapist, drama',
#   'mail': 'craigellis@yahoo.com',
#   'name': 'David Harris',
#   'residence': '4939 Willis Crossroad Suite 459\nSchmidtside, IA 62683',
#   'sex': 'M',
#   'ssn': '141-94-0503',
#   'username': 'allison90',
#   'website': ['https://walter-ward.biz/', 'http://keller.com/']},
#  {'address': '60539 Barnes Plains\nHarriston, MA 22752',
#   'birthdate': datetime.date(1970, 6, 17),
#   'blood_group': 'B-',
#   'company': 'Maxwell-Martinez',
#   'current_location': (Decimal('47.295548'), Decimal('-145.105022')),
#   'job': 'Psychologist, educational',
#   'mail': 'tiffanyblevins@yahoo.com',
#   'name': 'Kevin Martinez',
#   'residence': '408 James Drive\nEnglishmouth, CT 09902',
#   'sex': 'M',
#   'ssn': '713-10-1163',
#   'username': 'leedanielle',
#   'website': ['https://www.moody-hansen.com/']},
#  {'address': '5777 Acevedo Squares\nLawsonmouth, SC 48579',
#   'birthdate': datetime.date(2013, 2, 25),
#   'blood_group': 'B-',
#   'company': 'Hudson, Romero and Sandoval',
#   'current_location': (Decimal('-11.989423'), Decimal('-136.328933')),
#   'job': 'Public affairs consultant',
#   'mail': 'timothycastaneda@gmail.com',
#   'name': 'Gerald Robinson',
#   'residence': 'USNS Johnson\nFPO AA 01165',
#   'sex': 'M',
#   'ssn': '770-43-1867',
#   'username': 'claytongarrison',
#   'website': ['http://hartman.org/',
#    'http://hines-martin.biz/',
#    'http://www.hampton.com/']},
#  {'address': '41614 Robles Tunnel\nNew Denisehaven, DC 19302',
#   'birthdate': datetime.date(1916, 3, 3),
#   'blood_group': 'B-',
#   'company': 'Higgins-Garcia',
#   'current_location': (Decimal('63.988482'), Decimal('-18.820332')),
#   'job': 'Drilling engineer',
#   'mail': 'efreeman@hotmail.com',
#   'name': 'Alicia Ray',
#   'residence': '9535 Walker Terrace\nHenryport, MA 82687',
#   'sex': 'F',
#   'ssn': '632-58-6961',
#   'username': 'kevin28',
#   'website': ['https://nguyen.com/']},
#  {'address': '72147 Mary Vista Suite 483\nNicholasmouth, WI 42217',
#   'birthdate': datetime.date(2007, 10, 24),
#   'blood_group': 'AB-',
#   'company': 'Kim PLC',
#   'current_location': (Decimal('-27.412154'), Decimal('-141.226013')),
#   'job': 'Building services engineer',
#   'mail': 'twoods@hotmail.com',
#   'name': 'Chad Barrera',
#   'residence': '9467 Karen Burg\nSouth Kim, CO 44595',
#   'sex': 'M',
#   'ssn': '460-47-3870',
#   'username': 'ijones',
#   'website': ['https://www.powers-hernandez.org/',
#    'http://www.parker-strong.org/',
#    'http://frank-fritz.com/']},
#  {'address': '188 Weber Burg\nLake Jessica, MA 23357',
#   'birthdate': datetime.date(1973, 3, 16),
#   'blood_group': 'O-',
#   'company': 'Harris, Lambert and Johnson',
#   'current_location': (Decimal('81.563984'), Decimal('138.525412')),
#   'job': 'Advertising copywriter',
#   'mail': 'ricardotownsend@hotmail.com',
#   'name': 'Jennifer Palmer',
#   'residence': '1025 Amanda Manors\nSouth Lorifurt, TN 34301',
#   'sex': 'F',
#   'ssn': '742-46-6233',
#   'username': 'keith56',
#   'website': ['http://www.ramos-paul.biz/']},
#  {'address': '448 Hopkins Falls\nNew Jenniferburgh, FL 64637',
#   'birthdate': datetime.date(2008, 9, 14),
#   'blood_group': 'B-',
#   'company': 'Jones and Sons',
#   'current_location': (Decimal('78.0759905'), Decimal('-106.511857')),
#   'job': 'Occupational psychologist',
#   'mail': 'samantha09@yahoo.com',
#   'name': 'Kevin Smith',
#   'residence': '1921 Adams Circle Suite 955\nDavenportchester, UT 05994',
#   'sex': 'M',
#   'ssn': '632-62-4014',
#   'username': 'jamie66',
#   'website': ['http://davis.com/',
#    'http://www.robertson.net/',
#    'http://burns-ramirez.org/',
#    'https://osborn.com/']},
#  {'address': '0435 Justin Squares\nSouth Nicholasview, MD 45011',
#   'birthdate': datetime.date(1959, 4, 26),
#   'blood_group': 'AB-',
#   'company': 'Spears-Baker',
#   'current_location': (Decimal('-21.594761'), Decimal('78.115645')),
#   'job': 'Land',
#   'mail': 'riveraandrew@hotmail.com',
#   'name': 'Charles Campos',
#   'residence': 'USCGC Bautista\nFPO AE 88595',
#   'sex': 'M',
#   'ssn': '612-48-7897',
#   'username': 'ulawrence',
#   'website': ['http://ramos.org/', 'http://www.hall.net/']},
#  {'address': '194 Munoz Bypass Suite 583\nJohnsonhaven, MS 15711',
#   'birthdate': datetime.date(1908, 8, 3),
#   'blood_group': 'O+',
#   'company': 'Reynolds-Nelson',
#   'current_location': (Decimal('-84.4646365'), Decimal('113.012898')),
#   'job': 'Programmer, systems',
#   'mail': 'igonzales@yahoo.com',
#   'name': 'Jason Newman',
#   'residence': '72867 Laura Tunnel\nKennethland, NM 79855',
#   'sex': 'M',
#   'ssn': '069-22-6473',
#   'username': 'taguilar',
#   'website': ['http://matthews.com/',
#    'http://gould.org/',
#    'https://www.ward.com/']},
#  {'address': '50292 David Extensions Suite 833\nGreenshire, UT 81599',
#   'birthdate': datetime.date(1987, 1, 22),
#   'blood_group': 'AB-',
#   'company': 'Morris, Ali and Martinez',
#   'current_location': (Decimal('79.3636705'), Decimal('-37.263614')),
#   'job': 'Farm manager',
#   'mail': 'alexandriawheeler@hotmail.com',
#   'name': 'Michael Stewart',
#   'residence': '69639 Jon Isle\nWest Keithton, ND 25320',
#   'sex': 'M',
#   'ssn': '821-90-9277',
#   'username': 'laurahansen',
#   'website': ['https://www.oneal.com/', 'https://www.davidson-young.info/']},
#  {'address': '7609 Tammy Cliff\nPort Robertbury, NH 52271',
#   'birthdate': datetime.date(1949, 3, 2),
#   'blood_group': 'A-',
#   'company': 'Harrison-Wallace',
#   'current_location': (Decimal('-72.5349025'), Decimal('-103.146010')),
#   'job': 'Academic librarian',
#   'mail': 'elizabethsellers@hotmail.com',
#   'name': 'Carolyn Baker',
#   'residence': '5440 Mallory Mount\nPort Thomasbury, MD 64036',
#   'sex': 'F',
#   'ssn': '291-63-5238',
#   'username': 'vhawkins',
#   'website': ['https://richardson.biz/', 'https://www.potter.info/']},
#  {'address': '2185 Michelle Junctions Suite 502\nPort Marissaland, ND 14816',
#   'birthdate': datetime.date(2019, 1, 5),
#   'blood_group': 'AB+',
#   'company': 'Mccann Ltd',
#   'current_location': (Decimal('-82.1717765'), Decimal('-93.180986')),
#   'job': 'Computer games developer',
#   'mail': 'samuel31@yahoo.com',
#   'name': 'Tonya Rosales',
#   'residence': '1342 Terri Manor\nEast Davidfurt, SD 48517',
#   'sex': 'F',
#   'ssn': '242-74-3188',
#   'username': 'jgraham',
#   'website': ['https://www.barnes.net/',
#    'https://www.stephenson.net/',
#    'http://ramos.com/',
#    'https://gallegos.com/']},
#  {'address': '75540 Julie Circle Apt. 292\nLopezstad, MD 15414',
#   'birthdate': datetime.date(1914, 10, 7),
#   'blood_group': 'AB-',
#   'company': 'Lawrence and Sons',
#   'current_location': (Decimal('87.284750'), Decimal('126.311500')),
#   'job': 'Materials engineer',
#   'mail': 'jonesbrenda@hotmail.com',
#   'name': 'Tommy Jefferson',
#   'residence': '14090 Dwayne Shoals\nGreenestad, CT 51513',
#   'sex': 'M',
#   'ssn': '556-27-3759',
#   'username': 'hjohnson',
#   'website': ['https://beard-rasmussen.com/',
#    'https://www.curry-hunter.biz/',
#    'https://www.powell.com/',
#    'http://edwards.com/']},
#  {'address': '362 Fisher Flats Apt. 989\nKathleenstad, OK 78926',
#   'birthdate': datetime.date(1919, 7, 29),
#   'blood_group': 'B-',
#   'company': 'Mathis, Hendrix and Kennedy',
#   'current_location': (Decimal('63.960993'), Decimal('-36.374947')),
#   'job': 'Fashion designer',
#   'mail': 'johnreeves@hotmail.com',
#   'name': 'Sheryl Jones',
#   'residence': '77968 Craig Walk Suite 134\nJohnsonport, AK 69527',
#   'sex': 'F',
#   'ssn': '696-63-7877',
#   'username': 'michael93',
#   'website': ['http://pennington.com/']},
#  {'address': '10561 Jack Ridges Apt. 181\nNew David, NJ 23178',
#   'birthdate': datetime.date(1990, 4, 1),
#   'blood_group': 'O-',
#   'company': 'Livingston LLC',
#   'current_location': (Decimal('46.1740165'), Decimal('128.586532')),
#   'job': 'Conservator, furniture',
#   'mail': 'abigail68@gmail.com',
#   'name': 'Tracy Richardson',
#   'residence': 'USS Simon\nFPO AA 24740',
#   'sex': 'F',
#   'ssn': '290-30-6936',
#   'username': 'lcontreras',
#   'website': ['http://www.valdez-ritter.com/',
#    'http://www.beck.com/',
#    'https://nelson.net/',
#    'https://conner.net/']},
#  {'address': '6747 Brown Island Suite 090\nEast Alexis, MA 19453',
#   'birthdate': datetime.date(1945, 10, 25),
#   'blood_group': 'A-',
#   'company': 'Tran, Bolton and Williams',
#   'current_location': (Decimal('43.6321445'), Decimal('-122.936307')),
#   'job': 'Research scientist (life sciences)',
#   'mail': 'valdezshane@hotmail.com',
#   'name': 'Kimberly Gonzalez',
#   'residence': '599 Rebecca Mills\nSouth Elizabethburgh, MA 70937',
#   'sex': 'F',
#   'ssn': '112-69-0289',
#   'username': 'tscott',
#   'website': ['https://www.brooks.com/']},
#  {'address': '572 Courtney Well\nPort Margaret, ND 51771',
#   'birthdate': datetime.date(1935, 12, 4),
#   'blood_group': 'O-',
#   'company': 'Reyes, Vega and Thompson',
#   'current_location': (Decimal('-40.046984'), Decimal('148.252262')),
#   'job': 'Speech and language therapist',
#   'mail': 'fwoods@hotmail.com',
#   'name': 'Jacob Collier',
#   'residence': '3128 Taylor Islands\nKelleymouth, MO 46709',
#   'sex': 'M',
#   'ssn': '533-02-6324',
#   'username': 'kestrada',
#   'website': ['http://jones.com/', 'http://www.wright-mcgrath.org/']},
#  {'address': '57371 Alexa Trace Apt. 110\nSouth Jillian, SD 77806',
#   'birthdate': datetime.date(1992, 10, 29),
#   'blood_group': 'AB+',
#   'company': 'Rivera LLC',
#   'current_location': (Decimal('26.6478235'), Decimal('-23.445066')),
#   'job': 'Engineer, land',
#   'mail': 'alyssamayo@hotmail.com',
#   'name': 'Johnathan Guzman',
#   'residence': 'Unit 1018 Box 3511\nDPO AA 94277',
#   'sex': 'M',
#   'ssn': '291-49-2476',
#   'username': 'amcbride',
#   'website': ['https://baker-wolfe.com/',
#    'http://benitez.com/',
#    'https://www.barker.info/',
#    'https://williams.biz/']},
#  {'address': '73524 Myers Rest Suite 425\nNorth Lorraine, CO 54632',
#   'birthdate': datetime.date(1960, 8, 15),
#   'blood_group': 'AB+',
#   'company': 'Ward, Morales and Walter',
#   'current_location': (Decimal('-51.0224135'), Decimal('123.544476')),
#   'job': 'Warehouse manager',
#   'mail': 'tracy65@hotmail.com',
#   'name': 'Jennifer Cox',
#   'residence': 'USNS King\nFPO AP 38918',
#   'sex': 'F',
#   'ssn': '490-45-5245',
#   'username': 'johndavis',
#   'website': ['http://banks.com/']},
#  {'address': '057 Peter Roads Suite 592\nSusanburgh, SD 43487',
#   'birthdate': datetime.date(1917, 4, 1),
#   'blood_group': 'B+',
#   'company': 'Rice, Price and Jackson',
#   'current_location': (Decimal('-73.203076'), Decimal('24.694396')),
#   'job': "Nurse, children's",
#   'mail': 'stevewatts@yahoo.com',
#   'name': 'Tammy Cox',
#   'residence': '2264 White Motorway Suite 071\nLake Jamesview, WI 48463',
#   'sex': 'F',
#   'ssn': '456-23-1540',
#   'username': 'kathleenbarajas',
#   'website': ['http://herrera.com/',
#    'http://www.kennedy.com/',
#    'http://saunders.com/',
#    'http://www.lewis.com/']},
#  {'address': '31294 Gross Views Suite 684\nWest Chris, NJ 79961',
#   'birthdate': datetime.date(1976, 3, 27),
#   'blood_group': 'AB-',
#   'company': 'Rodriguez, Ramirez and Scott',
#   'current_location': (Decimal('50.4636425'), Decimal('-176.067929')),
#   'job': 'Volunteer coordinator',
#   'mail': 'gloria01@gmail.com',
#   'name': 'Laura Hanson',
#   'residence': '392 Anderson Cape\nLake Pamelamouth, DE 95690',
#   'sex': 'F',
#   'ssn': '241-46-6334',
#   'username': 'sarah62',
#   'website': ['http://shepherd.com/', 'https://www.meyer-green.biz/']},
#  {'address': '893 Martinez Gateway Apt. 762\nWest Williambury, MT 50147',
#   'birthdate': datetime.date(1936, 10, 5),
#   'blood_group': 'B-',
#   'company': 'Hernandez, Smith and Reed',
#   'current_location': (Decimal('85.984414'), Decimal('23.698180')),
#   'job': 'Chief Technology Officer',
#   'mail': 'kim93@gmail.com',
#   'name': 'Kelly Holloway',
#   'residence': '3020 Robinson Trail Apt. 620\nPort Deborahfort, MO 73938',
#   'sex': 'F',
#   'ssn': '108-03-4155',
#   'username': 'kfleming',
#   'website': ['http://douglas.biz/',
#    'https://stewart.com/',
#    'https://garcia-miller.com/',
#    'http://www.mccormick.info/']},
#  {'address': '79243 Leah Burgs\nLake Kristytown, AR 47179',
#   'birthdate': datetime.date(1963, 10, 21),
#   'blood_group': 'O-',
#   'company': 'Williams Ltd',
#   'current_location': (Decimal('-31.0504965'), Decimal('173.061634')),
#   'job': 'Investment banker, corporate',
#   'mail': 'michael22@gmail.com',
#   'name': 'Anthony Hughes',
#   'residence': 'PSC 3874, Box 2269\nAPO AE 18568',
#   'sex': 'M',
#   'ssn': '157-32-0088',
#   'username': 'michael07',
#   'website': ['http://www.stevens.com/',
#    'https://www.cook-rios.biz/',
#    'http://wolf.com/',
#    'http://howe.com/']},
#  {'address': '2445 Brandon Mews\nWeberborough, SC 33558',
#   'birthdate': datetime.date(1969, 7, 16),
#   'blood_group': 'AB-',
#   'company': 'Young-Fleming',
#   'current_location': (Decimal('-77.304052'), Decimal('100.913438')),
#   'job': 'Teacher, English as a foreign language',
#   'mail': 'danieljames@hotmail.com',
#   'name': 'Jacob Johnson',
#   'residence': '085 Lindsay Drive Suite 978\nMonicaland, AK 53935',
#   'sex': 'M',
#   'ssn': '097-81-3901',
#   'username': 'jeffrey98',
#   'website': ['http://mendez-murray.com/']},
#  {'address': '3918 Williams Port\nMarialand, MT 94798',
#   'birthdate': datetime.date(1943, 8, 11),
#   'blood_group': 'O-',
#   'company': 'Patterson and Sons',
#   'current_location': (Decimal('12.241711'), Decimal('129.105002')),
#   'job': 'Dealer',
#   'mail': 'alewis@hotmail.com',
#   'name': 'Shawn Martinez',
#   'residence': '297 Peterson Shoal\nSouth Taraburgh, NE 62287',
#   'sex': 'M',
#   'ssn': '416-95-1862',
#   'username': 'linda59',
#   'website': ['https://rojas.com/',
#    'https://torres.info/',
#    'https://www.morris.biz/',
#    'https://www.fowler-lester.biz/']},
#  ...]

# %%
import random
def stocks():
    '''
    This function uses the faker module to generate 100 different company names
    Then we use namedtupes to create Stock info such as company name, symbol, opening maket rate, closing market rate and highest rate touched
    '''
    comp = []
    Stock = namedtuple('Stock', 'company_name symbol open high close')
    for i in range(100):
        company_name = fake.company()
        symbol = company_name+str(i)
        open = random.uniform(1000,10000)
        high = open * random.uniform(1,2)
        close = open * random.uniform(0.5,1)
        comp.append(Stock(company_name=company_name, symbol=symbol, open=open, high=high, close=close))
    return comp
stocks()
# Out:
# [Stock(company_name='Brown, Jennings and Tran', symbol='Brown, Jennings and Tran0', open=5243.3011888588035, high=6867.801707126491, close=2872.6405580120554),
#  Stock(company_name='Garcia, Perez and Davis', symbol='Garcia, Perez and Davis1', open=1467.9420926747975, high=2438.2875869715895, close=988.6602840711516),
#  Stock(company_name='Boyer-Morales', symbol='Boyer-Morales2', open=4979.649844679142, high=8376.23731978627, close=2764.7952275752846),
#  Stock(company_name='Mccall, Gardner and Lopez', symbol='Mccall, Gardner and Lopez3', open=4656.689519349511, high=8769.477771901747, close=2450.6101291426),
#  Stock(company_name='Owen, Collins and Carr', symbol='Owen, Collins and Carr4', open=9866.757249964743, high=12857.38969480655, close=5149.949234939252),
#  Stock(company_name='Graham and Sons', symbol='Graham and Sons5', open=3370.546421139914, high=4211.110251830413, close=3320.358040398918),
#  Stock(company_name='Ruiz PLC', symbol='Ruiz PLC6', open=6295.583508562503, high=12539.91295633834, close=4570.271744093284),
#  Stock(company_name='Atkins, Benton and Garner', symbol='Atkins, Benton and Garner7', open=5774.570991022409, high=8514.847427005012, close=3588.227359369279),
#  Stock(company_name='Nelson PLC', symbol='Nelson PLC8', open=1898.0436961257533, high=2529.6042672888107, close=1573.9274541236778),
#  Stock(company_name='Joyce LLC', symbol='Joyce LLC9', open=6933.400528661403, high=13686.235704748167, close=5734.468473414671),
#  Stock(company_name='Wilson LLC', symbol='Wilson LLC10', open=4292.968963493937, high=7539.031079755621, close=2957.5111985892954),
#  Stock(company_name='Jones-Flowers', symbol='Jones-Flowers11', open=9194.531994406067, high=14497.33777093972, close=6711.903235187355),
#  Stock(company_name='Rosales, Lambert and Davis', symbol='Rosales, Lambert and Davis12', open=9906.112524913797, high=17469.28386242794, close=7843.379635370001),
#  Stock(company_name='Morris PLC', symbol='Morris PLC13', open=1183.9411089939606, high=1651.4540153937842, close=847.3121359280686),
#  Stock(company_name='Knight-Garcia', symbol='Knight-Garcia14', open=2431.2210419057556, high=2738.459924356838, close=1493.0218159563315),
#  Stock(company_name='Morrow-Rivera', symbol='Morrow-Rivera15', open=3470.468248311867, high=3776.3860995956916, close=2177.306835427661),
#  Stock(company_name='Morse Inc', symbol='Morse Inc16', open=9969.987737388386, high=14614.92666505943, close=8466.496590196637),
#  Stock(company_name='Oconnor-Reed', symbol='Oconnor-Reed17', open=4895.95269720907, high=6315.87184418741, close=4811.984026790417),
#  Stock(company_name='Ingram Ltd', symbol='Ingram Ltd18', open=3907.0722681756633, high=5297.3173907585315, close=3709.4648968912275),
#  Stock(company_name='Rice-Martin', symbol='Rice-Martin19', open=9900.092270956337, high=19721.805576581737, close=8509.473583364206),
#  Stock(company_name='Schmidt Group', symbol='Schmidt Group20', open=4304.466761257673, high=8474.594536390408, close=4043.538750446236),
#  Stock(company_name='Luna-Berg', symbol='Luna-Berg21', open=9313.493890172636, high=11320.48110006361, close=6200.3073843266275),
#  Stock(company_name='Murray-Wright', symbol='Murray-Wright22', open=3703.4659453186323, high=3943.61285884966, close=2488.509998056509),
#  Stock(company_name='Montoya, Johnston and Lucero', symbol='Montoya, Johnston and Lucero23', open=5865.296806775049, high=10244.855714668245, close=5016.404496339885),
#  Stock(company_name='May Group', symbol='May Group24', open=4880.4887765163185, high=6617.515265200518, close=4570.541671371275),
#  Stock(company_name='Buchanan, Hines and Peterson', symbol='Buchanan, Hines and Peterson25', open=1309.2017399851702, high=2072.5064584744614, close=1305.764297227729),
#  Stock(company_name='Johnson Inc', symbol='Johnson Inc26', open=3690.826921583025, high=5379.674324456856, close=3633.6843277670023),
#  Stock(company_name='Rangel, Chavez and Poole', symbol='Rangel, Chavez and Poole27', open=1328.672621918608, high=1744.7318855417311, close=1078.5050802819414),
#  Stock(company_name='Martin, Smith and Davis', symbol='Martin, Smith and Davis28', open=3475.5573871221895, high=6365.263101518359, close=2471.6638424615403),
#  Stock(company_name='Riley-Garcia', symbol='Riley-Garcia29', open=4336.014404869493, high=4408.776354124842, close=2239.52603132127),
#  Stock(company_name='Martin Ltd', symbol='Martin Ltd30', open=2962.538458008302, high=4564.978414712417, close=2360.8167076389286),
#  Stock(company_name='Ward LLC', symbol='Ward LLC31', open=4854.413211603247, high=9627.99059961246, close=4406.967301567108),
#  Stock(company_name='Black, Shepherd and Jones', symbol='Black, Shepherd and Jones32', open=7716.625657558476, high=13563.330552253394, close=5900.647010456863),
#  Stock(company_name='English-Payne', symbol='English-Payne33', open=5071.644563895608, high=9590.65854978667, close=5010.619591324922),
#  Stock(company_name='Benitez-Brooks', symbol='Benitez-Brooks34', open=6479.200572588234, high=8739.983382595894, close=5282.689456238817),
#  Stock(company_name='Bradley-Schultz', symbol='Bradley-Schultz35', open=3702.472074328246, high=6980.971970787218, close=2037.0006717084057),
#  Stock(company_name='Silva-Sanford', symbol='Silva-Sanford36', open=7431.533569984207, high=9478.31477087394, close=5428.457313081085),
#  Stock(company_name='Perkins-Cook', symbol='Perkins-Cook37', open=4055.990450022135, high=5819.021561808585, close=3939.989428925692),
#  Stock(company_name='Thompson, Mcpherson and King', symbol='Thompson, Mcpherson and King38', open=3144.7730365498796, high=5895.835439537289, close=1961.2466583131231),
#  Stock(company_name='Tanner-Chen', symbol='Tanner-Chen39', open=1504.1420659335236, high=1682.177329545068, close=1079.000349923186),
#  Stock(company_name='Hubbard-Delgado', symbol='Hubbard-Delgado40', open=1267.3393467147819, high=1584.0232866311926, close=1230.6749391761768),
#  Stock(company_name='Smith, Garcia and Parsons', symbol='Smith, Garcia and Parsons41', open=6959.914604837507, high=10345.440925929457, close=6764.132691860621),
#  Stock(company_name='Young, Rush and Byrd', symbol='Young, Rush and Byrd42', open=5959.875325511114, high=6729.230622479704, close=3560.900255729479),
#  Stock(company_name='Barr and Sons', symbol='Barr and Sons43', open=9014.957745201355, high=11220.617601521035, close=7435.777064084907),
#  Stock(company_name='Esparza, Jones and Hooper', symbol='Esparza, Jones and Hooper44', open=4085.4000210410663, high=7426.174367823164, close=3524.5004612668254),
#  Stock(company_name='Thomas-Hernandez', symbol='Thomas-Hernandez45', open=7481.759639144323, high=12940.021975856354, close=5588.649353244152),
#  Stock(company_name='Ball Group', symbol='Ball Group46', open=9281.153686827896, high=11097.34510832743, close=9242.162970522784),
#  Stock(company_name='Garcia, Williams and Young', symbol='Garcia, Williams and Young47', open=4038.087398233213, high=5829.261748959342, close=2229.262616925669),
#  Stock(company_name='Floyd-Moore', symbol='Floyd-Moore48', open=8589.066066097485, high=15443.488160772089, close=5764.42983788112),
#  Stock(company_name='Mcdaniel PLC', symbol='Mcdaniel PLC49', open=1595.7058305497126, high=1747.1702872982873, close=1254.2022952310965),
#  Stock(company_name='Green-Barker', symbol='Green-Barker50', open=4502.336032441401, high=6775.2454919191405, close=2900.2621599467443),
#  Stock(company_name='Morris-Rodriguez', symbol='Morris-Rodriguez51', open=5641.0078871771675, high=7271.92047123988, close=4137.107280657477),
#  Stock(company_name='Carrillo, Frederick and Williams', symbol='Carrillo, Frederick and Williams52', open=2244.6677421211157, high=2834.0063268607096, close=1622.1672350801216),
#  Stock(company_name='Coffey-Gray', symbol='Coffey-Gray53', open=7643.47812649545, high=14991.643032067652, close=5469.809923071636),
#  Stock(company_name='Schultz Ltd', symbol='Schultz Ltd54', open=8211.75700529719, high=10231.301121698829, close=4148.859196088744),
#  Stock(company_name='Greene, Jones and Jones', symbol='Greene, Jones and Jones55', open=4362.56802662181, high=6524.123752948597, close=2369.0247987462394),
#  Stock(company_name='Christensen-Bennett', symbol='Christensen-Bennett56', open=6635.4936016815755, high=11459.574898294268, close=6108.498568403189),
#  Stock(company_name='Schroeder and Sons', symbol='Schroeder and Sons57', open=8751.328274480966, high=15329.269285170632, close=7257.162671121879),
#  Stock(company_name='Escobar-Lewis', symbol='Escobar-Lewis58', open=8370.717905790796, high=10920.475846197853, close=6076.669195008002),
#  Stock(company_name='Graham-Wilson', symbol='Graham-Wilson59', open=1063.3182253925443, high=1821.1408891599067, close=820.6925693176172),
#  Stock(company_name='Johnson LLC', symbol='Johnson LLC60', open=9019.940800023543, high=10919.382561557026, close=7611.07374526126),
#  Stock(company_name='Mendoza, Barnett and Wood', symbol='Mendoza, Barnett and Wood61', open=5326.087877438478, high=8371.56670104575, close=4535.891204534775),
#  Stock(company_name='Johnston-Jimenez', symbol='Johnston-Jimenez62', open=6144.477774596534, high=11919.119205548002, close=5174.197282101576),
#  Stock(company_name='Fitzpatrick LLC', symbol='Fitzpatrick LLC63', open=8525.759978063681, high=10524.995656140723, close=4325.417660936125),
#  Stock(company_name='Best, Thompson and Jones', symbol='Best, Thompson and Jones64', open=1116.75868626618, high=2003.0871500211308, close=599.6321621267829),
#  Stock(company_name='Bell-Hopkins', symbol='Bell-Hopkins65', open=4757.061110473887, high=7072.310985304569, close=3083.2690795154776),
#  Stock(company_name='Alvarado-Lynch', symbol='Alvarado-Lynch66', open=8204.624632771356, high=9441.787276094356, close=4742.928906673734),
#  Stock(company_name='Mcdonald and Sons', symbol='Mcdonald and Sons67', open=1957.0813676236385, high=3031.259785184719, close=1616.426816667804),
#  Stock(company_name='Rodriguez-Thornton', symbol='Rodriguez-Thornton68', open=7569.214947094361, high=10980.497184612019, close=6513.861018049156),
#  Stock(company_name='Moore-Chambers', symbol='Moore-Chambers69', open=3405.8605691444886, high=5223.134736816886, close=2598.630090389902),
#  Stock(company_name='Hunter, Navarro and Peterson', symbol='Hunter, Navarro and Peterson70', open=7971.831323307877, high=14623.15230520629, close=7395.551018685076),
#  Stock(company_name='Lamb LLC', symbol='Lamb LLC71', open=9812.500275641947, high=9957.80429046407, close=8112.169138809807),
#  Stock(company_name='Powell-Ramirez', symbol='Powell-Ramirez72', open=2264.3920474097386, high=4137.665951037091, close=1266.9636426972718),
#  Stock(company_name='Foley Inc', symbol='Foley Inc73', open=8651.493574220283, high=11944.670213182746, close=6344.0504111487935),
#  Stock(company_name='Lewis Inc', symbol='Lewis Inc74', open=1294.558140032764, high=1713.0354111263669, close=1147.3926813762198),
#  Stock(company_name='Morales, Turner and Bell', symbol='Morales, Turner and Bell75', open=2927.6726315351616, high=3792.178320786065, close=1810.559677016484),
#  Stock(company_name='Moody, Foster and Burns', symbol='Moody, Foster and Burns76', open=7760.954924041172, high=11859.825241491737, close=6328.947091887804),
#  Stock(company_name='Nelson LLC', symbol='Nelson LLC77', open=8460.08587378463, high=16880.730720928015, close=6618.025659395062),
#  Stock(company_name='Skinner Group', symbol='Skinner Group78', open=2802.9051415489484, high=3628.5328483014623, close=1913.5808064504943),
#  Stock(company_name='Gutierrez, Park and Brown', symbol='Gutierrez, Park and Brown79', open=4896.917243045588, high=9600.723339037459, close=3024.431324023032),
#  Stock(company_name='Chung, Tucker and Chambers', symbol='Chung, Tucker and Chambers80', open=7041.463152516495, high=8023.654808924587, close=5031.304432680933),
#  Stock(company_name='Moore-Myers', symbol='Moore-Myers81', open=6111.198956096589, high=7507.977560877825, close=5732.519109688545),
#  Stock(company_name='Watson, Hansen and Mathis', symbol='Watson, Hansen and Mathis82', open=7262.653646718637, high=11740.128021650919, close=6292.065311914181),
#  Stock(company_name='Salinas, Mckee and Hill', symbol='Salinas, Mckee and Hill83', open=2773.9499337195584, high=4036.962344559031, close=2304.7661893288177),
#  Stock(company_name='Cole-Gonzalez', symbol='Cole-Gonzalez84', open=6781.758262015302, high=9120.066887919376, close=3865.974082438592),
#  Stock(company_name='Morton PLC', symbol='Morton PLC85', open=1719.0120494390146, high=2589.122574378644, close=1083.1503240944635),
#  Stock(company_name='Whitney Inc', symbol='Whitney Inc86', open=1820.371950992869, high=3103.926665769464, close=1622.313767444318),
#  Stock(company_name='Davis-Long', symbol='Davis-Long87', open=3499.0660896894087, high=4200.23753916745, close=2853.9467990751605),
#  Stock(company_name='Wilkinson-Adkins', symbol='Wilkinson-Adkins88', open=3064.754601468768, high=5112.582640203498, close=3009.914531748291),
#  Stock(company_name='Hamilton-Davis', symbol='Hamilton-Davis89', open=7235.251422559124, high=8105.394129580854, close=4804.991063236984),
#  Stock(company_name='Medina, Graham and Armstrong', symbol='Medina, Graham and Armstrong90', open=6628.801425393517, high=10607.585753359404, close=5431.236521647345),
#  Stock(company_name='Jones and Sons', symbol='Jones and Sons91', open=1605.2014488255575, high=2442.5518491328257, close=1448.018803407786),
#  Stock(company_name='Coleman, Morris and Benson', symbol='Coleman, Morris and Benson92', open=9775.97632797721, high=16332.879545768468, close=6365.009452237756),
#  Stock(company_name='Deleon, Harris and King', symbol='Deleon, Harris and King93', open=4600.636170619908, high=6233.339063211792, close=3888.6249790738816),
#  Stock(company_name='Woodward, Le and Murray', symbol='Woodward, Le and Murray94', open=8912.934961104751, high=13707.304273336287, close=6746.65239554022),
#  Stock(company_name='Washington, Walton and Kim', symbol='Washington, Walton and Kim95', open=9216.972105207338, high=13019.358962136757, close=6956.489992666315),
#  Stock(company_name='Williams-Gray', symbol='Williams-Gray96', open=2393.7727174656166, high=3303.92335512017, close=1938.693803442751),
#  Stock(company_name='Kelly, Baker and Brown', symbol='Kelly, Baker and Brown97', open=3498.4443024194397, high=5353.2531878321315, close=2449.6565286787186),
#  Stock(company_name='Hale-Chambers', symbol='Hale-Chambers98', open=7341.451438297558, high=10513.556924529346, close=4946.129372688403),
#  Stock(company_name='Johnson Group', symbol='Johnson Group99', open=6220.737310357254, high=10245.760141657332, close=4105.079320363528)]

# %%
def test_docs():
    assert stocks.__doc__,"doc string missing"
test_docs()

# %%
def test_stocks_len():
    s = stocks()
    assert len(s) == 100, "generated companies should be 100 in number"
test_stocks_len()

# %%
def test_profile_len():
    fp = fake_profile()
    assert len(fp) == 10000, "generated profiles should be 10000 in number"
test_profile_len()
# Out:
# 0:00:19.082664

# %%
'''
- To use faker module we need to:
```
from faker import Faker
fake = Faker()
```

# fake_profile
- This function is used to generate 10000 profiles using the faker module in python
- It stores all this data in namedtuple
- Named tuple is created like this: faker_profile = namedtuple('faker_profile',fake.profile().keys())
- One of the profile output look like this:
-  faker_profile(job='Industrial buyer', company='Russell Ltd', ssn='670-84-0587', residence='203 Tamara Squares\nPort Thomas, AK 38875', current_location=(Decimal('-52.392212'), Decimal('63.932851')), blood_group='A-', website=['https://reed-marshall.com/', 'http://www.campbell-medina.com/', 'http://www.calhoun.com/'], username='larry83', name='Larry Lopez', sex='M', address='91027 Castro Gateway\nEdwardsmouth, TN 44989', mail='canderson@gmail.com', birthdate=datetime.date(1980, 12, 27)),

# calculate
- This function uses the above mentioned faker profiles and calculates various aspects
- This function calculates the maximum blood_group, average current location, oldest person age and average age

# fake_profile_dict
- This function is used to generate 10000 profiles using the faker module in python
- It stores all this data in dictionary

# stocks
- This function uses the faker module to generate 100 different company names
- Then we use namedtupes to create Stock info such as company name, symbol, opening maket rate, closing market rate and highest rate touched
- The symbol is generated by adding a unique integer value after the name of the company
- Everything is then stored in the form of named tuples
- Example of how the Stock tuple looks:
- Stock(company_name='Kelly, Baker and Brown', symbol='Kelly, Baker and Brown97', open=3498.4443024194397, high=5353.2531878321315, close=2449.6565286787186),

'''
